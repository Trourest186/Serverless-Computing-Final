# %%
import matplotlib.pyplot as plot
import csv
import numpy as np
import random
import scipy

confidence_level = 0.90
z_value = scipy.stats.norm.ppf((1 + confidence_level) / 2)

# %%
# # add lables for all data -- For Prof. Hossfeld's lecture only
# import os
# # label = [timestamp_UNIX, timestamp, pod_number, power, CPU, GPU, Mem, NETpacket, task]
# directory = '../data/source_data/4G/mec/data/resource/mec'
# for filename in os.listdir(directory):
#     if filename.endswith('30_6_2023_8h16.csv'):
#         file_path = os.path.join(directory, filename)
        
#         # Read the existing CSV file
#         with open(file_path, 'r') as file:
#             reader = csv.reader(file)
#             rows = list(reader)
        
#         # Add labels to the first row of the CSV file
#         labels = ['timestamp_UNIX', 'timestamp', 'pod_number', 'power', 'CPU', 'GPU', 'Mem', 'NETpacket','repeat','task']  # Modify this list with your actual labels
        
#         rows.insert(0, labels)
        
#         # Write the updated CSV file
#         with open(file_path, 'w', newline='') as file:
#             writer = csv.writer(file)
#             writer.writerows(rows)

# %%
average_ram_null_state = []
average_cpu_null_state = []
average_gpu_null_state = []
average_power_null_state = []
average_energy_null_state = []
average_bw_null_state = []

average_ram_warm_disk_state = []
average_cpu_warm_disk_state = []
average_gpu_warm_disk_state = []
average_power_warm_disk_state = []
average_energy_warm_disk_state = []
average_bw_warm_disk_state = []

average_ram_warm_cpu_state = []
average_cpu_warm_cpu_state = []
average_gpu_warm_cpu_state = []
average_power_warm_cpu_state = []
average_energy_warm_cpu_state = []
average_bw_warm_cpu_state = []

average_ram_warm_mem_state = []
average_cpu_warm_mem_state = []
average_gpu_warm_mem_state = []
average_power_warm_mem_state = []
average_energy_warm_mem_state = []
average_bw_warm_mem_state = []

average_ram_active_state = []
average_cpu_active_state = []
average_gpu_active_state = []
average_power_active_state = []
average_energy_active_state = []
average_bw_active_state = []

average_ram_cold_state = []
average_cpu_cold_state = []
average_gpu_cold_state = []
average_power_cold_state = []
average_energy_cold_state = []
average_bw_cold_state = []

average_ram_null_to_cold_process = []
average_cpu_null_to_cold_process = []
average_power_null_to_cold_process = []
average_bw_null_to_cold_process = []
average_energy_null_to_cold_process = []

average_ram_warm_disk_to_warm_cpu_process = []
average_cpu_warm_disk_to_warm_cpu_process = []
average_power_warm_disk_to_warm_cpu_process = []
average_bw_warm_disk_to_warm_cpu_process = []
average_energy_warm_disk_to_warm_cpu_process = []

average_ram_warm_cpu_to_warm_disk_process = []
average_cpu_warm_cpu_to_warm_disk_process = []
average_power_warm_cpu_to_warm_disk_process = []
average_bw_warm_cpu_to_warm_disk_process = []
average_energy_warm_cpu_to_warm_disk_process = []

average_ram_warm_mem_to_warm_disk_process = []
average_cpu_warm_mem_to_warm_disk_process = []
average_power_warm_mem_to_warm_disk_process = []
average_bw_warm_mem_to_warm_disk_process = []
average_energy_warm_mem_to_warm_disk_process = []


average_ram_cold_to_warm_disk_process = []
average_cpu_cold_to_warm_disk_process = []
average_power_cold_to_warm_disk_process = []
average_bw_cold_to_warm_disk_process = []
average_energy_cold_to_warm_disk_process = []

average_power_active_to_warm_disk_process = []
average_cpu_active_to_warm_disk_process = []
average_ram_active_to_warm_disk_process = []
average_bw_active_to_warm_disk_process = []
average_energy_active_to_warm_disk_process = []

average_power_warm_disk_to_cold_process = []
average_cpu_warm_disk_to_cold_process = []
average_ram_warm_disk_to_cold_process = []
average_bw_warm_disk_to_cold_process = []
average_energy_warm_disk_to_cold_process = []

average_power_cold_to_null_process = []
average_cpu_cold_to_null_process = []
average_ram_cold_to_null_process = []
average_bw_cold_to_null_process = []
average_energy_cold_to_null_process = []

# %%
average_ram_null_state_1 = []
average_cpu_null_state_1 = []
average_gpu_null_state_1 = []
average_power_null_state_1 = []
average_energy_null_state_1 = []
average_bw_null_state_1 = []

average_ram_warm_disk_state_1 = []
average_cpu_warm_disk_state_1 = []
average_gpu_warm_disk_state_1 = []
average_power_warm_disk_state_1 = []
average_energy_warm_disk_state_1 = []
average_bw_warm_disk_state_1 = []

average_ram_warm_cpu_state_1 = []
average_cpu_warm_cpu_state_1 = []
average_gpu_warm_cpu_state_1 = []
average_power_warm_cpu_state_1 = []
average_energy_warm_cpu_state_1 = []
average_bw_warm_cpu_state_1 = []

average_ram_warm_mem_state_1 = []
average_cpu_warm_mem_state_1 = []
average_gpu_warm_mem_state_1 = []
average_power_warm_mem_state_1 = []
average_energy_warm_mem_state_1 = []
average_bw_warm_mem_state_1 = []

average_ram_active_state_1 = []
average_cpu_active_state_1 = []
average_gpu_active_state_1 = []
average_power_active_state_1 = []
average_energy_active_state_1 = []
average_bw_active_state_1 = []

average_ram_cold_state_1 = []
average_cpu_cold_state_1 = []
average_gpu_cold_state_1 = []
average_power_cold_state_1 = []
average_energy_cold_state_1 = []
average_bw_cold_state_1 = []

average_ram_null_to_cold_process_1 = []
average_cpu_null_to_cold_process_1 = []
average_power_null_to_cold_process_1 = []
average_bw_null_to_cold_process_1 = []
average_energy_null_to_cold_process_1 = []

average_ram_warm_disk_to_warm_cpu_process_1 = []
average_cpu_warm_disk_to_warm_cpu_process_1 = []
average_power_warm_disk_to_warm_cpu_process_1 = []
average_bw_warm_disk_to_warm_cpu_process_1 = []
average_energy_warm_disk_to_warm_cpu_process_1 = []

average_ram_warm_cpu_to_warm_disk_process_1 = []
average_cpu_warm_cpu_to_warm_disk_process_1 = []
average_power_warm_cpu_to_warm_disk_process_1 = []
average_bw_warm_cpu_to_warm_disk_process_1 = []
average_energy_warm_cpu_to_warm_disk_process_1 = []

average_ram_warm_mem_to_warm_disk_process_1 = []
average_cpu_warm_mem_to_warm_disk_process_1 = []
average_power_warm_mem_to_warm_disk_process_1 = []
average_bw_warm_mem_to_warm_disk_process_1 = []
average_energy_warm_mem_to_warm_disk_process_1 = []

average_ram_cold_to_warm_disk_process_1 = []
average_cpu_cold_to_warm_disk_process_1 = []
average_power_cold_to_warm_disk_process_1 = []
average_bw_cold_to_warm_disk_process_1 = []
average_energy_cold_to_warm_disk_process_1 = []

average_power_active_to_warm_disk_process_1 = []
average_cpu_active_to_warm_disk_process_1 = []
average_ram_active_to_warm_disk_process_1 = []
average_bw_active_to_warm_disk_process_1 = []
average_energy_active_to_warm_disk_process_1 = []

average_power_warm_disk_to_cold_process_1 = []
average_cpu_warm_disk_to_cold_process_1 = []
average_ram_warm_disk_to_cold_process_1 = []
average_bw_warm_disk_to_cold_process_1 = []
average_energy_warm_disk_to_cold_process_1 = []

average_power_cold_to_null_process_1 = []
average_cpu_cold_to_null_process_1 = []
average_ram_cold_to_null_process_1 = []
average_bw_cold_to_null_process_1 = []
average_energy_cold_to_null_process_1 = []

# %%
average_ram_null_state_2 = []
average_cpu_null_state_2 = []
average_gpu_null_state_2 = []
average_power_null_state_2 = []
average_energy_null_state_2 = []
average_bw_null_state_2 = []

average_ram_warm_disk_state_2 = []
average_cpu_warm_disk_state_2 = []
average_gpu_warm_disk_state_2 = []
average_power_warm_disk_state_2 = []
average_energy_warm_disk_state_2 = []
average_bw_warm_disk_state_2 = []

average_ram_warm_cpu_state_2 = []
average_cpu_warm_cpu_state_2 = []
average_gpu_warm_cpu_state_2 = []
average_power_warm_cpu_state_2 = []
average_energy_warm_cpu_state_2 = []
average_bw_warm_cpu_state_2 = []

average_ram_warm_mem_state_2 = []
average_cpu_warm_mem_state_2 = []
average_gpu_warm_mem_state_2 = []
average_power_warm_mem_state_2 = []
average_energy_warm_mem_state_2 = []
average_bw_warm_mem_state_2 = []

average_ram_active_state_2 = []
average_cpu_active_state_2 = []
average_gpu_active_state_2 = []
average_power_active_state_2 = []
average_energy_active_state_2 = []
average_bw_active_state_2 = []

average_ram_cold_state_2 = []
average_cpu_cold_state_2 = []
average_gpu_cold_state_2 = []
average_power_cold_state_2 = []
average_energy_cold_state_2 = []
average_bw_cold_state_2 = []

average_ram_null_to_cold_process_2 = []
average_cpu_null_to_cold_process_2 = []
average_power_null_to_cold_process_2 = []
average_bw_null_to_cold_process_2 = []
average_energy_null_to_cold_process_2 = []

average_ram_warm_disk_to_warm_cpu_process_2 = []
average_cpu_warm_disk_to_warm_cpu_process_2 = []
average_power_warm_disk_to_warm_cpu_process_2 = []
average_bw_warm_disk_to_warm_cpu_process_2 = []
average_energy_warm_disk_to_warm_cpu_process_2 = []

average_ram_warm_cpu_to_warm_disk_process_2 = []
average_cpu_warm_cpu_to_warm_disk_process_2 = []
average_power_warm_cpu_to_warm_disk_process_2 = []
average_bw_warm_cpu_to_warm_disk_process_2 = []
average_energy_warm_cpu_to_warm_disk_process_2 = []

average_ram_warm_mem_to_warm_disk_process_2 = []
average_cpu_warm_mem_to_warm_disk_process_2 = []
average_power_warm_mem_to_warm_disk_process_2 = []
average_bw_warm_mem_to_warm_disk_process_2 = []
average_energy_warm_mem_to_warm_disk_process_2 = []

average_ram_cold_to_warm_disk_process_2 = []
average_cpu_cold_to_warm_disk_process_2 = []
average_power_cold_to_warm_disk_process_2 = []
average_bw_cold_to_warm_disk_process_2 = []
average_energy_cold_to_warm_disk_process_2 = []

average_power_active_to_warm_disk_process_2 = []
average_cpu_active_to_warm_disk_process_2 = []
average_ram_active_to_warm_disk_process_2 = []
average_bw_active_to_warm_disk_process_2 = []
average_energy_active_to_warm_disk_process_2 = []

average_power_warm_disk_to_cold_process_2 = []
average_cpu_warm_disk_to_cold_process_2 = []
average_ram_warm_disk_to_cold_process_2 = []
average_bw_warm_disk_to_cold_process_2 = []
average_energy_warm_disk_to_cold_process_2 = []

average_power_cold_to_null_process_2 = []
average_cpu_cold_to_null_process_2 = []
average_ram_cold_to_null_process_2 = []
average_bw_cold_to_null_process_2 = []
average_energy_cold_to_null_process_2 = []

# %%
# For multipe container
for i in range(1,6):
    file_name = "/home/kien/kiem/serverless-giang/data/resource/mec/mix/x86_pod_2_rep_"+str(i)+"_1212024_12h17.csv"
    #STATES
    ram_null_state = []
    cpu_null_state = []
    gpu_null_state = []
    power_null_state = []
    energy_null_state = []
    bw_null_state = []

    ram_warm_disk_state = []
    cpu_warm_disk_state = []
    gpu_warm_disk_state = []
    power_warm_disk_state = []
    energy_warm_disk_state = []
    bw_warm_disk_state = []

    ram_warm_cpu_state = []
    cpu_warm_cpu_state = []
    gpu_warm_cpu_state = []
    power_warm_cpu_state = []
    energy_warm_cpu_state = []
    bw_warm_cpu_state = []

    ram_active_state = []
    cpu_active_state = []
    gpu_active_state = []
    power_active_state = []
    energy_active_state = []
    bw_active_state = []

    ram_cold_state = []
    cpu_cold_state = []
    gpu_cold_state = []
    power_cold_state = []
    energy_cold_state = []
    bw_cold_state = []

    #PROCESS
    power_null_to_cold_process = []
    cpu_null_to_cold_process = []
    ram_null_to_cold_process = []
    bw_null_to_cold_process = []
    energy_null_to_cold_process = []

    power_warm_disk_to_warm_cpu_process = []
    cpu_warm_disk_to_warm_cpu_process = []
    ram_warm_disk_to_warm_cpu_process = []
    bw_warm_disk_to_warm_cpu_process = []
    energy_warm_disk_to_warm_cpu_process = []

    power_warm_cpu_to_warm_disk_process = []
    cpu_warm_cpu_to_warm_disk_process = []
    ram_warm_cpu_to_warm_disk_process = []
    bw_warm_cpu_to_warm_disk_process = []
    energy_warm_cpu_to_warm_disk_process = []


    power_cold_to_warm_disk_process = []
    cpu_cold_to_warm_disk_process = []
    ram_cold_to_warm_disk_process = []
    bw_cold_to_warm_disk_process = []
    energy_cold_to_warm_disk_process = []

    power_active_to_warm_disk_process = []
    cpu_active_to_warm_disk_process = []
    ram_active_to_warm_disk_process = []
    bw_active_to_warm_disk_process = []
    energy_active_to_warm_disk_process = []

    power_warm_disk_to_cold_process = []
    cpu_warm_disk_to_cold_process = []
    ram_warm_disk_to_cold_process = []
    bw_warm_disk_to_cold_process = []
    energy_warm_disk_to_cold_process = []

    power_cold_to_null_process = []
    cpu_cold_to_null_process = []
    ram_cold_to_null_process = []
    bw_cold_to_null_process = []
    energy_cold_to_null_process = []

    with open(file_name, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            if row[9] == "null_state":
                power_null_state.append(float(row[3]))
                energy_null_state.append(float(row[4]))
                cpu_null_state.append(float(row[5]))
                gpu_null_state.append((float(row[6]))*100)
                ram_null_state.append(float(row[7]))
                bw_null_state.append(float(row[8]))
            elif row[9] == "warm_disk_state":
                power_warm_disk_state.append(float(row[3]))
                energy_warm_disk_state.append(float(row[4]))
                cpu_warm_disk_state.append(float(row[5]))
                gpu_warm_disk_state.append((float(row[6]))*100)
                ram_warm_disk_state.append(float(row[7]))
                bw_warm_disk_state.append(float(row[8]))
            elif row[9] == "warm_cpu_state":
                power_warm_cpu_state.append(float(row[3]))
                energy_warm_cpu_state.append(float(row[4]))
                cpu_warm_cpu_state.append(float(row[5]))
                gpu_warm_cpu_state.append((float(row[6]))*100)
                ram_warm_cpu_state.append(float(row[7]))
                bw_warm_cpu_state.append(float(row[8]))
            elif row[9] == "active_state":
                power_active_state.append(float(row[3]))
                energy_active_state.append(float(row[4]))
                cpu_active_state.append(float(row[5]))
                gpu_active_state.append((float(row[6]))*100)
                ram_active_state.append(float(row[7]))
                bw_active_state.append(float(row[8]))
            elif row[9] == "cold_state":
                power_cold_state.append(float(row[3]))
                energy_cold_state.append(float(row[4]))
                cpu_cold_state.append(float(row[5]))
                gpu_cold_state.append((float(row[6]))*100)
                ram_cold_state.append(float(row[7]))
                bw_cold_state.append(float(row[8]))
            elif row[9] == "null_to_cold_process":
                power_null_to_cold_process.append(float(row[3]))
                energy_null_to_cold_process.append(float(row[4]))
                cpu_null_to_cold_process.append(float(row[5]))
                ram_null_to_cold_process.append(float(row[7]))
                bw_null_to_cold_process.append(float(row[8]))
            elif row[9] == "warm_disk_to_warm_cpu_process":
                power_warm_disk_to_warm_cpu_process.append(float(row[3]))
                energy_warm_disk_to_warm_cpu_process.append(float(row[4]))
                cpu_warm_disk_to_warm_cpu_process.append(float(row[5]))
                ram_warm_disk_to_warm_cpu_process.append(float(row[7]))
                bw_warm_disk_to_warm_cpu_process.append(float(row[8]))
            elif row[9] == "warm_cpu_to_warm_disk_process":
                power_warm_cpu_to_warm_disk_process.append(float(row[3]))
                energy_warm_cpu_to_warm_disk_process.append(float(row[4]))
                cpu_warm_cpu_to_warm_disk_process.append(float(row[5]))
                ram_warm_cpu_to_warm_disk_process.append(float(row[7]))
                bw_warm_cpu_to_warm_disk_process.append(float(row[8]))
                #NOTE: self_generated
                power_active_to_warm_disk_process.append(float(row[3]))
                energy_active_to_warm_disk_process.append(float(row[4]))
                cpu_active_to_warm_disk_process.append(float(row[5]))
                ram_active_to_warm_disk_process.append(float(row[7]))
                bw_active_to_warm_disk_process.append(float(row[8]))
            elif row[9] == "cold_to_warm_disk_process":
                pass
                # power_cold_to_warm_disk_process.append(float(row[3]))
                # energy_cold_to_warm_disk_process.append(float(row[4]))
                # cpu_cold_to_warm_disk_process.append(float(row[5]))
                # ram_cold_to_warm_disk_process.append(float(row[7]))
                # bw_cold_to_warm_disk_process.append(float(row[7]))
            elif row[9] == "active_to_warm_disk_process":
                pass
                # power_active_to_warm_disk_process.append(float(row[3]))
                # cpu_active_to_warm_disk_process.append(float(row[4]))
                # ram_active_to_warm_disk_process.append((float(row[6]))*100)
                # bw_active_to_warm_disk_process.append(float(row[7]))
            elif row[9] == "warm_disk_to_cold_process":
                pass
                # power_warm_disk_to_cold_process.append(float(row[3]))
                # cpu_warm_disk_to_cold_process.append(float(row[4]))
                # ram_warm_disk_to_cold_process.append((float(row[6]))*100)
                # bw_warm_disk_to_cold_process.append(float(row[7]))
            elif row[9] == "cold_to_null_process":
                power_cold_to_null_process.append(float(row[3]))
                energy_cold_to_null_process.append(float(row[4]))
                cpu_cold_to_null_process.append(float(row[5]))
                ram_cold_to_null_process.append((float(row[7])))
                bw_cold_to_null_process.append(float(row[8]))

        #STATES
        average_cpu_null_state.append(np.mean(cpu_null_state))
        average_gpu_null_state.append(np.mean(gpu_null_state))
        average_ram_null_state.append(np.mean(ram_null_state))
        average_power_null_state.append(np.mean(power_null_state))
        average_bw_null_state.append((bw_null_state[-1]-bw_null_state[0])/(1024**2))
        average_energy_null_state.append(energy_null_state[-1]-energy_null_state[0])

        average_cpu_warm_disk_state.append(np.mean(cpu_warm_disk_state))
        average_gpu_warm_disk_state.append(np.mean(gpu_warm_disk_state))
        average_ram_warm_disk_state.append(np.mean(ram_warm_disk_state))
        average_power_warm_disk_state.append(np.mean(power_warm_disk_state))
        average_bw_warm_disk_state.append((bw_warm_disk_state[-1]-bw_warm_disk_state[0])/(1024**2))
        average_energy_warm_disk_state.append(energy_warm_disk_state[-1]-energy_warm_disk_state[0])

        average_cpu_warm_cpu_state.append(np.mean(cpu_warm_cpu_state))
        average_gpu_warm_cpu_state.append(np.mean(gpu_warm_cpu_state))
        average_ram_warm_cpu_state.append(np.mean(ram_warm_cpu_state))
        average_power_warm_cpu_state.append(np.mean(power_warm_cpu_state))
        average_bw_warm_cpu_state.append((bw_warm_cpu_state[-1]-bw_warm_cpu_state[0])/(1024**2))
        average_energy_warm_cpu_state.append(energy_warm_cpu_state[-1]-energy_warm_cpu_state[0])

        average_cpu_active_state.append(np.mean(cpu_active_state))
        average_gpu_active_state.append(np.mean(gpu_active_state))
        average_ram_active_state.append(np.mean(ram_active_state))
        average_power_active_state.append(np.mean(power_active_state))
        average_bw_active_state.append((bw_active_state[-1]-bw_active_state[0])/(1024**2))
        average_energy_active_state.append(energy_active_state[-1]-energy_active_state[0])

        average_cpu_cold_state.append(np.mean(cpu_cold_state))
        average_gpu_cold_state.append(np.mean(gpu_cold_state))
        average_ram_cold_state.append(np.mean(ram_cold_state))
        average_power_cold_state.append(np.mean(power_cold_state))
        average_bw_cold_state.append((bw_cold_state[-1]-bw_cold_state[0])/(1024**2))
        average_energy_cold_state.append(energy_cold_state[-1]-energy_cold_state[0])

        #PROCESS
        average_cpu_null_to_cold_process.append(np.mean(cpu_null_to_cold_process))
        average_ram_null_to_cold_process.append(np.mean(ram_null_to_cold_process))
        average_power_null_to_cold_process.append(np.mean(power_null_to_cold_process))
        average_energy_null_to_cold_process.append((energy_null_to_cold_process[-1]-energy_null_to_cold_process[0]))
        average_bw_null_to_cold_process.append((bw_null_to_cold_process[-1]-bw_null_to_cold_process[0])/(1024**2))

        average_cpu_warm_disk_to_warm_cpu_process.append(np.mean(cpu_warm_disk_to_warm_cpu_process))
        average_ram_warm_disk_to_warm_cpu_process.append(np.mean(ram_warm_disk_to_warm_cpu_process))
        average_power_warm_disk_to_warm_cpu_process.append(np.mean(power_warm_disk_to_warm_cpu_process))
        average_energy_warm_disk_to_warm_cpu_process.append(energy_warm_disk_to_warm_cpu_process[-1]-energy_warm_disk_to_warm_cpu_process[0])
        average_bw_warm_disk_to_warm_cpu_process.append((bw_warm_disk_to_warm_cpu_process[-1]-bw_warm_disk_to_warm_cpu_process[0])/(1024**2))

        average_cpu_warm_cpu_to_warm_disk_process.append(np.mean(cpu_warm_cpu_to_warm_disk_process))
        average_ram_warm_cpu_to_warm_disk_process.append(np.mean(ram_warm_cpu_to_warm_disk_process))
        average_power_warm_cpu_to_warm_disk_process.append(np.mean(power_warm_cpu_to_warm_disk_process))
        average_energy_warm_cpu_to_warm_disk_process.append(energy_warm_cpu_to_warm_disk_process[-1]-energy_warm_cpu_to_warm_disk_process[0])
        average_bw_warm_cpu_to_warm_disk_process.append((bw_warm_cpu_to_warm_disk_process[-1]-bw_warm_cpu_to_warm_disk_process[0])/(1024**2))

        # average_cpu_cold_to_warm_disk_process.append(np.mean(cpu_cold_to_warm_disk_process))
        # average_ram_cold_to_warm_disk_process.append(np.mean(ram_cold_to_warm_disk_process))
        # average_power_cold_to_warm_disk_process.append(np.mean(power_cold_to_warm_disk_process))
        # average_bw_cold_to_warm_disk_process.append((bw_cold_to_warm_disk_process[-1]-bw_cold_to_warm_disk_process[0])/(1024**2)) #Bandwidth = packet_after - packet_before

        average_cpu_active_to_warm_disk_process.append(np.mean(cpu_active_to_warm_disk_process))
        average_ram_active_to_warm_disk_process.append(np.mean(ram_active_to_warm_disk_process))
        ## NOTE: self_generated 
        average_power_active_to_warm_disk_process.append(np.mean(power_active_to_warm_disk_process)) 
        average_energy_active_to_warm_disk_process.append(energy_active_to_warm_disk_process[-1]-energy_active_to_warm_disk_process[0]) 
        average_bw_active_to_warm_disk_process.append((bw_active_to_warm_disk_process[-1]-bw_active_to_warm_disk_process[0])/(1024**2))

        # average_cpu_warm_disk_to_cold_process.append(np.mean(cpu_warm_disk_to_cold_process))
        # average_ram_warm_disk_to_cold_process.append(np.mean(ram_warm_disk_to_cold_process))
        # average_power_warm_disk_to_cold_process.append(np.mean(power_warm_disk_to_cold_process))
        # average_bw_warm_disk_to_cold_process.append((bw_warm_disk_to_cold_process[-1]-bw_warm_disk_to_cold_process[0])/(1024**2))

        average_cpu_cold_to_null_process.append(np.mean(cpu_cold_to_null_process))
        average_ram_cold_to_null_process.append(np.mean(ram_cold_to_null_process))
        average_power_cold_to_null_process.append(np.mean(power_cold_to_null_process))
        average_energy_cold_to_null_process.append(energy_cold_to_null_process[-1]-energy_cold_to_null_process[0])
        average_bw_cold_to_null_process.append((bw_cold_to_null_process[-1]-bw_cold_to_null_process[0])/(1024**2))

# %%
# Multiple pod
for i in range(1, 6):
    file_name = "/home/kien/kiem/serverless-giang/data/resource/mec/mix/x86_pod_1_rep_" + str(i) + "_1212024_9h3.csv"
    # STATES
    ram_null_state_2 = []
    cpu_null_state_2 = []
    gpu_null_state_2 = []
    power_null_state_2 = []
    energy_null_state_2 = []
    bw_null_state_2 = []

    ram_warm_disk_state_2 = []
    cpu_warm_disk_state_2 = []
    gpu_warm_disk_state_2 = []
    power_warm_disk_state_2 = []
    energy_warm_disk_state_2 = []
    bw_warm_disk_state_2 = []

    ram_warm_cpu_state_2 = []
    cpu_warm_cpu_state_2 = []
    gpu_warm_cpu_state_2 = []
    power_warm_cpu_state_2 = []
    energy_warm_cpu_state_2 = []
    bw_warm_cpu_state_2 = []

    ram_active_state_2 = []
    cpu_active_state_2 = []
    gpu_active_state_2 = []
    power_active_state_2 = []
    energy_active_state_2 = []
    bw_active_state_2 = []

    ram_cold_state_2 = []
    cpu_cold_state_2 = []
    gpu_cold_state_2 = []
    power_cold_state_2 = []
    energy_cold_state_2 = []
    bw_cold_state_2 = []

    # PROCESS
    power_null_to_cold_process_2 = []
    cpu_null_to_cold_process_2 = []
    ram_null_to_cold_process_2 = []
    bw_null_to_cold_process_2 = []
    energy_null_to_cold_process_2 = []

    power_warm_disk_to_warm_cpu_process_2 = []
    cpu_warm_disk_to_warm_cpu_process_2 = []
    ram_warm_disk_to_warm_cpu_process_2 = []
    bw_warm_disk_to_warm_cpu_process_2 = []
    energy_warm_disk_to_warm_cpu_process_2 = []

    power_warm_cpu_to_warm_disk_process_2 = []
    cpu_warm_cpu_to_warm_disk_process_2 = []
    ram_warm_cpu_to_warm_disk_process_2 = []
    bw_warm_cpu_to_warm_disk_process_2 = []
    energy_warm_cpu_to_warm_disk_process_2 = []

    power_cold_to_warm_disk_process_2 = []
    cpu_cold_to_warm_disk_process_2 = []
    ram_cold_to_warm_disk_process_2 = []
    bw_cold_to_warm_disk_process_2 = []
    energy_cold_to_warm_disk_process_2 = []

    power_active_to_warm_disk_process_2 = []
    cpu_active_to_warm_disk_process_2 = []
    ram_active_to_warm_disk_process_2 = []
    bw_active_to_warm_disk_process_2 = []
    energy_active_to_warm_disk_process_2 = []

    power_warm_disk_to_cold_process_2 = []
    cpu_warm_disk_to_cold_process_2 = []
    ram_warm_disk_to_cold_process_2 = []
    bw_warm_disk_to_cold_process_2 = []
    energy_warm_disk_to_cold_process_2 = []

    power_cold_to_null_process_2 = []
    cpu_cold_to_null_process_2 = []
    ram_cold_to_null_process_2 = []
    bw_cold_to_null_process_2 = []
    energy_cold_to_null_process_2 = []

    with open(file_name, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            if row[9] == "null_state":
                power_null_state_2.append(float(row[3]))
                energy_null_state_2.append(float(row[4]))
                cpu_null_state_2.append(float(row[5]))
                gpu_null_state_2.append((float(row[6])) * 100)
                ram_null_state_2.append(float(row[7]))
                bw_null_state_2.append(float(row[8]))
            elif row[9] == "warm_disk_state":
                power_warm_disk_state_2.append(float(row[3]))
                energy_warm_disk_state_2.append(float(row[4]))
                cpu_warm_disk_state_2.append(float(row[5]))
                gpu_warm_disk_state_2.append((float(row[6])) * 100)
                ram_warm_disk_state_2.append(float(row[7]))
                bw_warm_disk_state_2.append(float(row[8]))
            elif row[9] == "warm_cpu_state":
                power_warm_cpu_state_2.append(float(row[3]))
                energy_warm_cpu_state_2.append(float(row[4]))
                cpu_warm_cpu_state_2.append(float(row[5]))
                gpu_warm_cpu_state_2.append((float(row[6])) * 100)
                ram_warm_cpu_state_2.append(float(row[7]))
                bw_warm_cpu_state_2.append(float(row[8]))
            elif row[9] == "active_state":
                power_active_state_2.append(float(row[3]))
                energy_active_state_2.append(float(row[4]))
                cpu_active_state_2.append(float(row[5]))
                gpu_active_state_2.append((float(row[6])) * 100)
                ram_active_state_2.append(float(row[7]))
                bw_active_state_2.append(float(row[8]))
            elif row[9] == "cold_state":
                power_cold_state_2.append(float(row[3]))
                energy_cold_state_2.append(float(row[4]))
                cpu_cold_state_2.append(float(row[5]))
                gpu_cold_state_2.append((float(row[6])) * 100)
                ram_cold_state_2.append(float(row[7]))
                bw_cold_state_2.append(float(row[8]))
            elif row[9] == "null_to_cold_process":
                power_null_to_cold_process_2.append(float(row[3]))
                energy_null_to_cold_process_2.append(float(row[4]))
                cpu_null_to_cold_process_2.append(float(row[5]))
                ram_null_to_cold_process_2.append(float(row[7]))
                bw_null_to_cold_process_2.append(float(row[8]))
            elif row[9] == "warm_disk_to_warm_cpu_process":
                power_warm_disk_to_warm_cpu_process_2.append(float(row[3]))
                energy_warm_disk_to_warm_cpu_process_2.append(float(row[4]))
                cpu_warm_disk_to_warm_cpu_process_2.append(float(row[5]))
                ram_warm_disk_to_warm_cpu_process_2.append(float(row[7]))
                bw_warm_disk_to_warm_cpu_process_2.append(float(row[8]))
            elif row[9] == "warm_cpu_to_warm_disk_process":
                power_warm_cpu_to_warm_disk_process_2.append(float(row[3]))
                energy_warm_cpu_to_warm_disk_process_2.append(float(row[4]))
                cpu_warm_cpu_to_warm_disk_process_2.append(float(row[5]))
                ram_warm_cpu_to_warm_disk_process_2.append(float(row[7]))
                bw_warm_cpu_to_warm_disk_process_2.append(float(row[8]))
                power_active_to_warm_disk_process_2.append(float(row[3]))
                energy_active_to_warm_disk_process_2.append(float(row[4]))
                cpu_active_to_warm_disk_process_2.append(float(row[5]))
                ram_active_to_warm_disk_process_2.append(float(row[7]))
                bw_active_to_warm_disk_process_2.append(float(row[8]))
            elif row[9] == "cold_to_warm_disk_process":
                pass
            elif row[9] == "active_to_warm_disk_process":
                pass
            elif row[9] == "warm_disk_to_cold_process":
                pass
            elif row[9] == "cold_to_null_process":
                power_cold_to_null_process_2.append(float(row[3]))
                energy_cold_to_null_process_2.append(float(row[4]))
                cpu_cold_to_null_process_2.append(float(row[5]))
                ram_cold_to_null_process_2.append((float(row[7])))
                bw_cold_to_null_process_2.append(float(row[8]))

        # STATES
        average_cpu_null_state_2.append(np.mean(cpu_null_state_2))
        average_gpu_null_state_2.append(np.mean(gpu_null_state_2))
        average_ram_null_state_2.append(np.mean(ram_null_state_2))
        average_power_null_state_2.append(np.mean(power_null_state_2))
        average_bw_null_state_2.append((bw_null_state_2[-1]-bw_null_state_2[0])/(1024**2))
        average_energy_null_state_2.append(energy_null_state_2[-1]-energy_null_state_2[0])

        average_cpu_warm_disk_state_2.append(np.mean(cpu_warm_disk_state_2))
        average_gpu_warm_disk_state_2.append(np.mean(gpu_warm_disk_state_2))
        average_ram_warm_disk_state_2.append(np.mean(ram_warm_disk_state_2))
        average_power_warm_disk_state_2.append(np.mean(power_warm_disk_state_2))
        average_bw_warm_disk_state_2.append((bw_warm_disk_state_2[-1]-bw_warm_disk_state_2[0])/(1024**2))
        average_energy_warm_disk_state_2.append(energy_warm_disk_state_2[-1]-energy_warm_disk_state_2[0])

        average_cpu_warm_cpu_state_2.append(np.mean(cpu_warm_cpu_state_2))
        average_gpu_warm_cpu_state_2.append(np.mean(gpu_warm_cpu_state_2))
        average_ram_warm_cpu_state_2.append(np.mean(ram_warm_cpu_state_2))
        average_power_warm_cpu_state_2.append(np.mean(power_warm_cpu_state_2))
        average_bw_warm_cpu_state_2.append((bw_warm_cpu_state_2[-1]-bw_warm_cpu_state_2[0])/(1024**2))
        average_energy_warm_cpu_state_2.append(energy_warm_cpu_state_2[-1]-energy_warm_cpu_state_2[0])


        average_cpu_active_state_2.append(np.mean(cpu_active_state_2))
        average_gpu_active_state_2.append(np.mean(gpu_active_state_2))
        average_ram_active_state_2.append(np.mean(ram_active_state_2))
        average_power_active_state_2.append(np.mean(power_active_state_2))
        average_bw_active_state_2.append((bw_active_state_2[-1]-bw_active_state_2[0])/(1024**2))
        average_energy_active_state_2.append(energy_active_state_2[-1]-energy_active_state_2[0])


        average_cpu_cold_state_2.append(np.mean(cpu_cold_state_2))
        average_gpu_cold_state_2.append(np.mean(gpu_cold_state_2))
        average_ram_cold_state_2.append(np.mean(ram_cold_state_2))
        average_power_cold_state_2.append(np.mean(power_cold_state_2))
        average_bw_cold_state_2.append((bw_cold_state_2[-1]-bw_cold_state_2[0])/(1024**2))
        average_energy_cold_state_2.append(energy_cold_state_2[-1]-energy_cold_state_2[0])

        # PROCESS
        average_cpu_null_to_cold_process_2.append(np.mean(cpu_null_to_cold_process_2))
        average_ram_null_to_cold_process_2.append(np.mean(ram_null_to_cold_process_2))
        average_power_null_to_cold_process_2.append(np.mean(power_null_to_cold_process_2))
        average_energy_null_to_cold_process_2.append((energy_null_to_cold_process_2[-1]-energy_null_to_cold_process_2[0]))
        average_bw_null_to_cold_process_2.append((bw_null_to_cold_process_2[-1]-bw_null_to_cold_process_2[0])/(1024**2))

        average_cpu_warm_disk_to_warm_cpu_process_2.append(np.mean(cpu_warm_disk_to_warm_cpu_process_2))
        average_ram_warm_disk_to_warm_cpu_process_2.append(np.mean(ram_warm_disk_to_warm_cpu_process_2))
        average_power_warm_disk_to_warm_cpu_process_2.append(np.mean(power_warm_disk_to_warm_cpu_process_2))
        average_energy_warm_disk_to_warm_cpu_process_2.append(energy_warm_disk_to_warm_cpu_process_2[-1]-energy_warm_disk_to_warm_cpu_process_2[0])
        average_bw_warm_disk_to_warm_cpu_process_2.append((bw_warm_disk_to_warm_cpu_process_2[-1]-bw_warm_disk_to_warm_cpu_process_2[0])/(1024**2))

        average_cpu_warm_cpu_to_warm_disk_process_2.append(np.mean(cpu_warm_cpu_to_warm_disk_process_2))
        average_ram_warm_cpu_to_warm_disk_process_2.append(np.mean(ram_warm_cpu_to_warm_disk_process_2))
        average_power_warm_cpu_to_warm_disk_process_2.append(np.mean(power_warm_cpu_to_warm_disk_process_2))
        average_energy_warm_cpu_to_warm_disk_process_2.append(energy_warm_cpu_to_warm_disk_process_2[-1]-energy_warm_cpu_to_warm_disk_process_2[0])
        average_bw_warm_cpu_to_warm_disk_process_2.append((bw_warm_cpu_to_warm_disk_process_2[-1]-bw_warm_cpu_to_warm_disk_process_2[0])/(1024**2))

        # average_cpu_cold_to_warm_disk_process_2.append(np.mean(cpu_cold_to_warm_disk_process_2))
        # average_ram_cold_to_warm_disk_process_2.append(np.mean(ram_cold_to_warm_disk_process_2))
        # average_power_cold_to_warm_disk_process_2.append(np.mean(power_cold_to_warm_disk_process_2))
        # average_bw_cold_to_warm_disk_process_2.append((bw_cold_to_warm_disk_process_2[-1]-bw_cold_to_warm_disk_process_2[0])/(1024**2)) #Bandwidth = packet_after - packet_before

        average_cpu_active_to_warm_disk_process_2.append(np.mean(cpu_active_to_warm_disk_process_2))
        average_ram_active_to_warm_disk_process_2.append(np.mean(ram_active_to_warm_disk_process_2))
        ## NOTE: self_generated 
        average_power_active_to_warm_disk_process_2.append(np.mean(power_active_to_warm_disk_process_2)) 
        average_energy_active_to_warm_disk_process_2.append(energy_active_to_warm_disk_process_2[-1]-energy_active_to_warm_disk_process_2[0]) 
        average_bw_active_to_warm_disk_process_2.append((bw_active_to_warm_disk_process_2[-1]-bw_active_to_warm_disk_process_2[0])/(1024**2))

        # average_cpu_warm_disk_to_cold_process_2.append(np.mean(cpu_warm_disk_to_cold_process_2))
        # average_ram_warm_disk_to_cold_process_2.append(np.mean(ram_warm_disk_to_cold_process_2))
        # average_power_warm_disk_to_cold_process_2.append(np.mean(power_warm_disk_to_cold_process_2))
        # average_bw_warm_disk_to_cold_process_2.append((bw_warm_disk_to_cold_process_2[-1]-bw_warm_disk_to_cold_process_2[0])/(1024**2))

        average_cpu_cold_to_null_process_2.append(np.mean(cpu_cold_to_null_process_2))
        average_ram_cold_to_null_process_2.append(np.mean(ram_cold_to_null_process_2))
        average_power_cold_to_null_process_2.append(np.mean(power_cold_to_null_process_2))
        average_energy_cold_to_null_process_2.append(energy_cold_to_null_process_2[-1]-energy_cold_to_null_process_2[0])
        average_bw_cold_to_null_process_2.append((bw_cold_to_null_process_2[-1]-bw_cold_to_null_process_2[0])/(1024**2))

# %%
# Multiple process
for i in range(1, 6):
    file_name = "/home/kien/kiem/serverless-giang/data/resource/mec/mix/x86_pod_1_rep_" + str(i) + "_1212024_10h28.csv"
    # STATES
    ram_null_state_1 = []
    cpu_null_state_1 = []
    gpu_null_state_1 = []
    power_null_state_1 = []
    energy_null_state_1 = []
    bw_null_state_1 = []

    ram_warm_disk_state_1 = []
    cpu_warm_disk_state_1 = []
    gpu_warm_disk_state_1 = []
    power_warm_disk_state_1 = []
    energy_warm_disk_state_1 = []
    bw_warm_disk_state_1 = []

    ram_warm_cpu_state_1 = []
    cpu_warm_cpu_state_1 = []
    gpu_warm_cpu_state_1 = []
    power_warm_cpu_state_1 = []
    energy_warm_cpu_state_1 = []
    bw_warm_cpu_state_1 = []

    ram_active_state_1 = []
    cpu_active_state_1 = []
    gpu_active_state_1 = []
    power_active_state_1 = []
    energy_active_state_1 = []
    bw_active_state_1 = []

    ram_cold_state_1 = []
    cpu_cold_state_1 = []
    gpu_cold_state_1 = []
    power_cold_state_1 = []
    energy_cold_state_1 = []
    bw_cold_state_1 = []

    # PROCESS
    power_null_to_cold_process_1 = []
    cpu_null_to_cold_process_1 = []
    ram_null_to_cold_process_1 = []
    bw_null_to_cold_process_1 = []
    energy_null_to_cold_process_1 = []

    power_warm_disk_to_warm_cpu_process_1 = []
    cpu_warm_disk_to_warm_cpu_process_1 = []
    ram_warm_disk_to_warm_cpu_process_1 = []
    bw_warm_disk_to_warm_cpu_process_1 = []
    energy_warm_disk_to_warm_cpu_process_1 = []

    power_warm_cpu_to_warm_disk_process_1 = []
    cpu_warm_cpu_to_warm_disk_process_1 = []
    ram_warm_cpu_to_warm_disk_process_1 = []
    bw_warm_cpu_to_warm_disk_process_1 = []
    energy_warm_cpu_to_warm_disk_process_1 = []

    power_cold_to_warm_disk_process_1 = []
    cpu_cold_to_warm_disk_process_1 = []
    ram_cold_to_warm_disk_process_1 = []
    bw_cold_to_warm_disk_process_1 = []
    energy_cold_to_warm_disk_process_1 = []

    power_active_to_warm_disk_process_1 = []
    cpu_active_to_warm_disk_process_1 = []
    ram_active_to_warm_disk_process_1 = []
    bw_active_to_warm_disk_process_1 = []
    energy_active_to_warm_disk_process_1 = []

    power_warm_disk_to_cold_process_1 = []
    cpu_warm_disk_to_cold_process_1 = []
    ram_warm_disk_to_cold_process_1 = []
    bw_warm_disk_to_cold_process_1 = []
    energy_warm_disk_to_cold_process_1 = []

    power_cold_to_null_process_1 = []
    cpu_cold_to_null_process_1 = []
    ram_cold_to_null_process_1 = []
    bw_cold_to_null_process_1 = []
    energy_cold_to_null_process_1 = []


    with open(file_name, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            if row[9] == "null_state":
                power_null_state_1.append(float(row[3]))
                energy_null_state_1.append(float(row[4]))
                cpu_null_state_1.append(float(row[5]))
                gpu_null_state_1.append((float(row[6])) * 100)
                ram_null_state_1.append(float(row[7]))
                bw_null_state_1.append(float(row[8]))
            elif row[9] == "warm_disk_state":
                power_warm_disk_state_1.append(float(row[3]))
                energy_warm_disk_state_1.append(float(row[4]))
                cpu_warm_disk_state_1.append(float(row[5]))
                gpu_warm_disk_state_1.append((float(row[6])) * 100)
                ram_warm_disk_state_1.append(float(row[7]))
                bw_warm_disk_state_1.append(float(row[8]))
            elif row[9] == "warm_cpu_state":
                power_warm_cpu_state_1.append(float(row[3]))
                energy_warm_cpu_state_1.append(float(row[4]))
                cpu_warm_cpu_state_1.append(float(row[5]))
                gpu_warm_cpu_state_1.append((float(row[6])) * 100)
                ram_warm_cpu_state_1.append(float(row[7]))
                bw_warm_cpu_state_1.append(float(row[8]))
            elif row[9] == "active_state":
                power_active_state_1.append(float(row[3]))
                energy_active_state_1.append(float(row[4]))
                cpu_active_state_1.append(float(row[5]))
                gpu_active_state_1.append((float(row[6])) * 100)
                ram_active_state_1.append(float(row[7]))
                bw_active_state_1.append(float(row[8]))
            elif row[9] == "cold_state":
                power_cold_state_1.append(float(row[3]))
                energy_cold_state_1.append(float(row[4]))
                cpu_cold_state_1.append(float(row[5]))
                gpu_cold_state_1.append((float(row[6])) * 100)
                ram_cold_state_1.append(float(row[7]))
                bw_cold_state_1.append(float(row[8]))
            elif row[9] == "null_to_cold_process":
                power_null_to_cold_process_1.append(float(row[3]))
                energy_null_to_cold_process_1.append(float(row[4]))
                cpu_null_to_cold_process_1.append(float(row[5]))
                ram_null_to_cold_process_1.append(float(row[7]))
                bw_null_to_cold_process_1.append(float(row[8]))
            elif row[9] == "warm_disk_to_warm_cpu_process":
                power_warm_disk_to_warm_cpu_process_1.append(float(row[3]))
                energy_warm_disk_to_warm_cpu_process_1.append(float(row[4]))
                cpu_warm_disk_to_warm_cpu_process_1.append(float(row[5]))
                ram_warm_disk_to_warm_cpu_process_1.append(float(row[7]))
                bw_warm_disk_to_warm_cpu_process_1.append(float(row[8]))
            elif row[9] == "warm_cpu_to_warm_disk_process":
                power_warm_cpu_to_warm_disk_process_1.append(float(row[3]))
                energy_warm_cpu_to_warm_disk_process_1.append(float(row[4]))
                cpu_warm_cpu_to_warm_disk_process_1.append(float(row[5]))
                ram_warm_cpu_to_warm_disk_process_1.append(float(row[7]))
                bw_warm_cpu_to_warm_disk_process_1.append(float(row[8]))
                power_active_to_warm_disk_process_1.append(float(row[3]))
                energy_active_to_warm_disk_process_1.append(float(row[4]))
                cpu_active_to_warm_disk_process_1.append(float(row[5]))
                ram_active_to_warm_disk_process_1.append(float(row[7]))
                bw_active_to_warm_disk_process_1.append(float(row[8]))
            elif row[9] == "cold_to_warm_disk_process":
                pass
            elif row[9] == "active_to_warm_disk_process":
                pass
            elif row[9] == "warm_disk_to_cold_process":
                pass
            elif row[9] == "cold_to_null_process":
                power_cold_to_null_process_1.append(float(row[3]))
                energy_cold_to_null_process_1.append(float(row[4]))
                cpu_cold_to_null_process_1.append(float(row[5]))
                ram_cold_to_null_process_1.append((float(row[7])))
                bw_cold_to_null_process_1.append(float(row[8]))


        # STATES
        # STATES
        average_cpu_null_state_1.append(np.mean(cpu_null_state_1))
        average_gpu_null_state_1.append(np.mean(gpu_null_state_1))
        average_ram_null_state_1.append(np.mean(ram_null_state_1))
        average_power_null_state_1.append(np.mean(power_null_state_1))
        average_bw_null_state_1.append((bw_null_state_1[-1]-bw_null_state_1[0])/(1024**2))
        average_energy_null_state_1.append(energy_null_state_1[-1]-energy_null_state_1[0])


        average_cpu_warm_disk_state_1.append(np.mean(cpu_warm_disk_state_1))
        average_gpu_warm_disk_state_1.append(np.mean(gpu_warm_disk_state_1))
        average_ram_warm_disk_state_1.append(np.mean(ram_warm_disk_state_1))
        average_power_warm_disk_state_1.append(np.mean(power_warm_disk_state_1))
        average_bw_warm_disk_state_1.append((bw_warm_disk_state_1[-1]-bw_warm_disk_state_1[0])/(1024**2))
        average_energy_warm_disk_state_1.append(energy_warm_disk_state_1[-1]-energy_warm_disk_state_1[0])


        average_cpu_warm_cpu_state_1.append(np.mean(cpu_warm_cpu_state_1))
        average_gpu_warm_cpu_state_1.append(np.mean(gpu_warm_cpu_state_1))
        average_ram_warm_cpu_state_1.append(np.mean(ram_warm_cpu_state_1))
        average_power_warm_cpu_state_1.append(np.mean(power_warm_cpu_state_1))
        average_bw_warm_cpu_state_1.append((bw_warm_cpu_state_1[-1]-bw_warm_cpu_state_1[0])/(1024**2))
        average_energy_warm_cpu_state_1.append(energy_warm_cpu_state_1[-1]-energy_warm_cpu_state_1[0])


        average_cpu_active_state_1.append(np.mean(cpu_active_state_1))
        average_gpu_active_state_1.append(np.mean(gpu_active_state_1))
        average_ram_active_state_1.append(np.mean(ram_active_state_1))
        average_power_active_state_1.append(np.mean(power_active_state_1))
        average_bw_active_state_1.append((bw_active_state_1[-1]-bw_active_state_1[0])/(1024**2))
        average_energy_active_state_1.append(energy_active_state_1[-1]-energy_active_state_1[0])


        average_cpu_cold_state_1.append(np.mean(cpu_cold_state_1))
        average_gpu_cold_state_1.append(np.mean(gpu_cold_state_1))
        average_ram_cold_state_1.append(np.mean(ram_cold_state_1))
        average_power_cold_state_1.append(np.mean(power_cold_state_1))
        average_bw_cold_state_1.append((bw_cold_state_1[-1]-bw_cold_state_1[0])/(1024**2))
        average_energy_cold_state_1.append(energy_cold_state_1[-1]-energy_cold_state_1[0])

        # PROCESS
        average_cpu_null_to_cold_process_1.append(np.mean(cpu_null_to_cold_process_1))
        average_ram_null_to_cold_process_1.append(np.mean(ram_null_to_cold_process_1))
        average_power_null_to_cold_process_1.append(np.mean(power_null_to_cold_process_1))
        average_energy_null_to_cold_process_1.append((energy_null_to_cold_process_1[-1]-energy_null_to_cold_process_1[0]))
        average_bw_null_to_cold_process_1.append((bw_null_to_cold_process_1[-1]-bw_null_to_cold_process_1[0])/(1024**2))

        average_cpu_warm_disk_to_warm_cpu_process_1.append(np.mean(cpu_warm_disk_to_warm_cpu_process_1))
        average_ram_warm_disk_to_warm_cpu_process_1.append(np.mean(ram_warm_disk_to_warm_cpu_process_1))
        average_power_warm_disk_to_warm_cpu_process_1.append(np.mean(power_warm_disk_to_warm_cpu_process_1))
        average_energy_warm_disk_to_warm_cpu_process_1.append(energy_warm_disk_to_warm_cpu_process_1[-1]-energy_warm_disk_to_warm_cpu_process_1[0])
        average_bw_warm_disk_to_warm_cpu_process_1.append((bw_warm_disk_to_warm_cpu_process_1[-1]-bw_warm_disk_to_warm_cpu_process_1[0])/(1024**2))

        average_cpu_warm_cpu_to_warm_disk_process_1.append(np.mean(cpu_warm_cpu_to_warm_disk_process_1))
        average_ram_warm_cpu_to_warm_disk_process_1.append(np.mean(ram_warm_cpu_to_warm_disk_process_1))
        average_power_warm_cpu_to_warm_disk_process_1.append(np.mean(power_warm_cpu_to_warm_disk_process_1))
        average_energy_warm_cpu_to_warm_disk_process_1.append(energy_warm_cpu_to_warm_disk_process_1[-1]-energy_warm_cpu_to_warm_disk_process_1[0])
        average_bw_warm_cpu_to_warm_disk_process_1.append((bw_warm_cpu_to_warm_disk_process_1[-1]-bw_warm_cpu_to_warm_disk_process_1[0])/(1024**2))

        # average_cpu_cold_to_warm_disk_process_1.append(np.mean(cpu_cold_to_warm_disk_process_1))
        # average_ram_cold_to_warm_disk_process_1.append(np.mean(ram_cold_to_warm_disk_process_1))
        # average_power_cold_to_warm_disk_process_1.append(np.mean(power_cold_to_warm_disk_process_1))
        # average_bw_cold_to_warm_disk_process_1.append((bw_cold_to_warm_disk_process_1[-1]-bw_cold_to_warm_disk_process_1[0])/(1024**2)) #Bandwidth = packet_after - packet_before

        average_cpu_active_to_warm_disk_process_1.append(np.mean(cpu_active_to_warm_disk_process_1))
        average_ram_active_to_warm_disk_process_1.append(np.mean(ram_active_to_warm_disk_process_1))
        ## NOTE: self_generated 
        average_power_active_to_warm_disk_process_1.append(np.mean(power_active_to_warm_disk_process_1)) 
        average_energy_active_to_warm_disk_process_1.append(energy_active_to_warm_disk_process_1[-1]-energy_active_to_warm_disk_process_1[0]) 
        average_bw_active_to_warm_disk_process_1.append((bw_active_to_warm_disk_process_1[-1]-bw_active_to_warm_disk_process_1[0])/(1024**2))

        # average_cpu_warm_disk_to_cold_process_1.append(np.mean(cpu_warm_disk_to_cold_process_1))
        # average_ram_warm_disk_to_cold_process_1.append(np.mean(ram_warm_disk_to_cold_process_1))
        # average_power_warm_disk_to_cold_process_1.append(np.mean(power_warm_disk_to_cold_process_1))
        # average_bw_warm_disk_to_cold_process_1.append((bw_warm_disk_to_cold_process_1[-1]-bw_warm_disk_to_cold_process_1[0])/(1024**2))

        average_cpu_cold_to_null_process_1.append(np.mean(cpu_cold_to_null_process_1))
        average_ram_cold_to_null_process_1.append(np.mean(ram_cold_to_null_process_1))
        average_power_cold_to_null_process_1.append(np.mean(power_cold_to_null_process_1))
        average_energy_cold_to_null_process_1.append(energy_cold_to_null_process_1[-1]-energy_cold_to_null_process_1[0])
        average_bw_cold_to_null_process_1.append((bw_cold_to_null_process_1[-1]-bw_cold_to_null_process_1[0])/(1024**2))

# %%
# for i in range(1,11):
#     file_name = "../data/source_data/wifi/data/resource/mec/x86_pod_1_rep_"+str(i)+"_12_7_2023_12h48.csv"
#     #STATES

#     ram_warm_mem_state = []
#     cpu_warm_mem_state = []
#     gpu_warm_mem_state = []
#     power_warm_mem_state = []

#     power_warm_mem_to_warm_disk_process = []
#     cpu_warm_mem_to_warm_disk_process = []
#     ram_warm_mem_to_warm_disk_process = []
#     energy_warm_mem_to_warm_disk_process = []
#     # bw_warm_mem_to_warm_disk_process = []

#     with open(file_name, newline='') as csvfile:
#         spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
#         for row in spamreader:
#             if row[9] == "warm_mem_state":
#                 power_warm_mem_state.append(float(row[3]))
#                 cpu_warm_mem_state.append(float(row[5]))
#                 gpu_warm_mem_state.append(float(row[6]))
#                 ram_warm_mem_state.append(float(row[7]))
#             elif row[9] == "warm_mem_to_warm_disk_process":
#                 pass
#                 power_warm_mem_to_warm_disk_process.append(float(row[3]))
#                 energy_warm_mem_to_warm_disk_process.append(float(row[4]))
#                 cpu_warm_mem_to_warm_disk_process.append(float(row[5]))
#                 ram_warm_mem_to_warm_disk_process.append(float(row[7]))
#                 # bw_warm_mem_to_warm_disk_process.append(float(row[7]))

#         #STATES
#         average_cpu_warm_mem_state.append(np.mean(cpu_warm_mem_state))
#         average_gpu_warm_mem_state.append(np.mean(gpu_warm_mem_state))
#         average_ram_warm_mem_state.append(np.mean(ram_warm_mem_state))
#         average_power_warm_mem_state.append(np.mean(power_warm_mem_state))


#         #PROCESS
        
#         average_cpu_warm_mem_to_warm_disk_process.append(np.mean(cpu_warm_mem_to_warm_disk_process))
#         average_ram_warm_mem_to_warm_disk_process.append(np.mean(ram_warm_mem_to_warm_disk_process))
#         average_power_warm_mem_to_warm_disk_process.append(np.mean(power_warm_mem_to_warm_disk_process))
#         average_energy_warm_mem_to_warm_disk_process.append(energy_warm_mem_to_warm_disk_process[-1]-energy_warm_mem_to_warm_disk_process[0])
#         # average_bw_warm_mem_to_warm_disk_process.append((bw_warm_mem_to_warm_disk_process[-1]-bw_warm_mem_to_warm_disk_process[0])/(1024**2))

# %%
#STATES
# Calculate the average
ram_null_state_mean = np.mean(average_ram_null_state)
cpu_null_state_mean = np.mean(average_cpu_null_state) 
gpu_null_state_mean = np.mean(average_gpu_null_state)
power_null_state_mean = np.mean(average_power_null_state)
bw_null_state_mean = np.mean(average_bw_null_state)
energy_null_state_mean = np.mean(average_energy_null_state)

ram_warm_mem_state_mean = np.mean(average_ram_warm_mem_state)
cpu_warm_mem_state_mean = np.mean(average_cpu_warm_mem_state)
gpu_warm_mem_state_mean = np.mean(average_gpu_warm_mem_state)
power_warm_mem_state_mean = np.mean(average_power_warm_mem_state) 
bw_warm_mem_state_mean = np.mean(average_bw_warm_mem_state) 
energy_warm_mem_state_mean = np.mean(average_energy_warm_mem_state)

ram_warm_disk_state_mean = np.mean(average_ram_warm_disk_state)
cpu_warm_disk_state_mean = np.mean(average_cpu_warm_disk_state) 
gpu_warm_disk_state_mean = np.mean(average_gpu_warm_disk_state)
power_warm_disk_state_mean = np.mean(average_power_warm_disk_state)
bw_warm_disk_state_mean = np.mean(average_bw_warm_disk_state)
energy_warm_disk_state_mean = np.mean(average_energy_warm_disk_state)

ram_warm_cpu_state_mean = np.mean(average_ram_warm_cpu_state) 
cpu_warm_cpu_state_mean = np.mean(average_cpu_warm_cpu_state)
gpu_warm_cpu_state_mean = np.mean(average_gpu_warm_cpu_state)
power_warm_cpu_state_mean = np.mean(average_power_warm_cpu_state)
bw_warm_cpu_state_mean = np.mean(average_bw_warm_cpu_state)
energy_warm_cpu_state_mean = np.mean(average_energy_warm_cpu_state)

ram_active_state_mean = np.mean(average_ram_active_state)
cpu_active_state_mean = np.mean(average_cpu_active_state)
gpu_active_state_mean = np.mean(average_gpu_active_state)
power_active_state_mean = np.mean(average_power_active_state)
bw_active_state_mean = np.mean(average_bw_active_state)
energy_active_state_mean = np.mean(average_energy_active_state)

ram_cold_state_mean = np.mean(average_ram_cold_state)
cpu_cold_state_mean = np.mean(average_cpu_cold_state)
gpu_cold_state_mean = np.mean(average_gpu_cold_state)
power_cold_state_mean = np.mean(average_power_cold_state)
bw_cold_state_mean = np.mean(average_bw_cold_state)
energy_cold_state_mean = np.mean(average_energy_cold_state)

# Calculate the standard deviation
# Null State
ram_null_state_std = np.std(average_ram_null_state) / np.sqrt(len(average_ram_null_state))
cpu_null_state_std = np.std(average_cpu_null_state) / np.sqrt(len(average_cpu_null_state))
gpu_null_state_std = np.std(average_gpu_null_state) / np.sqrt(len(average_gpu_null_state))
power_null_state_std = np.std(average_power_null_state) / np.sqrt(len(average_power_null_state))
bw_null_state_std = np.std(average_bw_null_state) / np.sqrt(len(average_bw_null_state))
energy_null_state_std = np.std(average_energy_null_state) / np.sqrt(len(average_energy_null_state))

# Warm Memory State
ram_warm_mem_state_std = np.std(average_ram_warm_mem_state) / np.sqrt(len(average_ram_warm_mem_state))
cpu_warm_mem_state_std = np.std(average_cpu_warm_mem_state) / np.sqrt(len(average_cpu_warm_mem_state))
gpu_warm_mem_state_std = np.std(average_gpu_warm_mem_state) / np.sqrt(len(average_gpu_warm_mem_state))
power_warm_mem_state_std = np.std(average_power_warm_mem_state) / np.sqrt(len(average_power_warm_mem_state))
bw_warm_mem_state_std = np.std(average_bw_warm_mem_state) / np.sqrt(len(average_bw_warm_mem_state))
energy_warm_mem_state_std = np.std(average_energy_warm_mem_state) / np.sqrt(len(average_energy_warm_mem_state))

# Warm Disk State
ram_warm_disk_state_std = np.std(average_ram_warm_disk_state) / np.sqrt(len(average_ram_warm_disk_state))
cpu_warm_disk_state_std = np.std(average_cpu_warm_disk_state) / np.sqrt(len(average_cpu_warm_disk_state))
gpu_warm_disk_state_std = np.std(average_gpu_warm_disk_state) / np.sqrt(len(average_gpu_warm_disk_state))
power_warm_disk_state_std = np.std(average_power_warm_disk_state) / np.sqrt(len(average_power_warm_disk_state))
bw_warm_disk_state_std = np.std(average_bw_warm_disk_state) / np.sqrt(len(average_bw_warm_disk_state))
energy_warm_disk_state_std = np.std(average_energy_warm_disk_state) / np.sqrt(len(average_energy_warm_disk_state))

# Warm CPU State
ram_warm_cpu_state_std = np.std(average_ram_warm_cpu_state) / np.sqrt(len(average_ram_warm_cpu_state))
cpu_warm_cpu_state_std = np.std(average_cpu_warm_cpu_state) / np.sqrt(len(average_cpu_warm_cpu_state))
gpu_warm_cpu_state_std = np.std(average_gpu_warm_cpu_state) / np.sqrt(len(average_gpu_warm_cpu_state))
power_warm_cpu_state_std = np.std(average_power_warm_cpu_state) / np.sqrt(len(average_power_warm_cpu_state))
bw_warm_cpu_state_std = np.std(average_bw_warm_cpu_state) / np.sqrt(len(average_bw_warm_cpu_state))
energy_warm_cpu_state_std = np.std(average_energy_warm_cpu_state) / np.sqrt(len(average_energy_warm_cpu_state))

# Active State
ram_active_state_std = np.std(average_ram_active_state) / np.sqrt(len(average_ram_active_state))
cpu_active_state_std = np.std(average_cpu_active_state) / np.sqrt(len(average_cpu_active_state))
gpu_active_state_std = np.std(average_gpu_active_state) / np.sqrt(len(average_gpu_active_state))
power_active_state_std = np.std(average_power_active_state) / np.sqrt(len(average_power_active_state))
bw_active_state_std = np.std(average_bw_active_state) / np.sqrt(len(average_bw_active_state))
energy_active_state_std = np.std(average_energy_active_state) / np.sqrt(len(average_energy_active_state))

# Cold State
ram_cold_state_std = np.std(average_ram_cold_state) / np.sqrt(len(average_ram_cold_state))
cpu_cold_state_std = np.std(average_cpu_cold_state) / np.sqrt(len(average_cpu_cold_state))
gpu_cold_state_std = np.std(average_gpu_cold_state) / np.sqrt(len(average_gpu_cold_state))
power_cold_state_std = np.std(average_power_cold_state) / np.sqrt(len(average_power_cold_state))
bw_cold_state_std = np.std(average_bw_cold_state) / np.sqrt(len(average_bw_cold_state))
energy_cold_state_std = np.std(average_energy_cold_state) / np.sqrt(len(average_energy_cold_state))
# Out:
# /home/kien/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/kien/.local/lib/python3.8/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/kien/.local/lib/python3.8/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/kien/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/kien/.local/lib/python3.8/site-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
#STATES
# Calculate the average
ram_null_state_mean_1 = np.mean(average_ram_null_state_1)
cpu_null_state_mean_1 = np.mean(average_cpu_null_state_1) 
gpu_null_state_mean_1 = np.mean(average_gpu_null_state_1)
power_null_state_mean_1 = np.mean(average_power_null_state_1)
bw_null_state_mean_1 = np.mean(average_bw_null_state_1)
energy_null_state_mean_1 = np.mean(average_energy_null_state_1)


ram_warm_mem_state_mean_1 = np.mean(average_ram_warm_mem_state_1)
cpu_warm_mem_state_mean_1 = np.mean(average_cpu_warm_mem_state_1)
gpu_warm_mem_state_mean_1 = np.mean(average_gpu_warm_mem_state_1)
power_warm_mem_state_mean_1 = np.mean(average_power_warm_mem_state_1) 
bw_warm_mem_state_mean_1 = np.mean(average_bw_warm_mem_state_1)
energy_warm_mem_state_mean_1 = np.mean(average_energy_warm_mem_state_1)


ram_warm_disk_state_mean_1 = np.mean(average_ram_warm_disk_state_1)
cpu_warm_disk_state_mean_1 = np.mean(average_cpu_warm_disk_state_1) 
gpu_warm_disk_state_mean_1 = np.mean(average_gpu_warm_disk_state_1)
power_warm_disk_state_mean_1 = np.mean(average_power_warm_disk_state_1)
bw_warm_disk_state_mean_1 = np.mean(average_bw_warm_disk_state_1)
energy_warm_disk_state_mean_1 = np.mean(average_energy_warm_disk_state_1)


ram_warm_cpu_state_mean_1 = np.mean(average_ram_warm_cpu_state_1) 
cpu_warm_cpu_state_mean_1 = np.mean(average_cpu_warm_cpu_state_1)
gpu_warm_cpu_state_mean_1 = np.mean(average_gpu_warm_cpu_state_1)
power_warm_cpu_state_mean_1 = np.mean(average_power_warm_cpu_state_1)
bw_warm_cpu_state_mean_1 = np.mean(average_bw_warm_cpu_state_1)
energy_warm_cpu_state_mean_1 = np.mean(average_energy_warm_cpu_state_1)


ram_active_state_mean_1 = np.mean(average_ram_active_state_1)
cpu_active_state_mean_1 = np.mean(average_cpu_active_state_1)
gpu_active_state_mean_1 = np.mean(average_gpu_active_state_1)
power_active_state_mean_1 = np.mean(average_power_active_state_1)
bw_active_state_mean_1 = np.mean(average_bw_active_state_1)
energy_active_state_mean_1 = np.mean(average_energy_active_state_1)


ram_cold_state_mean_1 = np.mean(average_ram_cold_state_1)
cpu_cold_state_mean_1 = np.mean(average_cpu_cold_state_1)
gpu_cold_state_mean_1 = np.mean(average_gpu_cold_state_1)
power_cold_state_mean_1 = np.mean(average_power_cold_state_1)
bw_cold_state_mean_1 = np.mean(average_bw_cold_state_1)
energy_cold_state_mean_1 = np.mean(average_energy_cold_state_1)


# Calculate the standard deviation
# Null State
ram_null_state_std_1 = np.std(average_ram_null_state_1) / np.sqrt(len(average_ram_null_state_1))
cpu_null_state_std_1 = np.std(average_cpu_null_state_1) / np.sqrt(len(average_cpu_null_state_1))
gpu_null_state_std_1 = np.std(average_gpu_null_state_1) / np.sqrt(len(average_gpu_null_state_1))
power_null_state_std_1 = np.std(average_power_null_state_1) / np.sqrt(len(average_power_null_state_1))
bw_null_state_std_1 = np.std(average_bw_null_state_1) / np.sqrt(len(average_bw_null_state_1))
energy_null_state_std_1 = np.std(average_energy_null_state_1) / np.sqrt(len(average_energy_null_state_1))

# Warm Memory State
ram_warm_mem_state_std_1 = np.std(average_ram_warm_mem_state_1) / np.sqrt(len(average_ram_warm_mem_state_1))
cpu_warm_mem_state_std_1 = np.std(average_cpu_warm_mem_state_1) / np.sqrt(len(average_cpu_warm_mem_state_1))
gpu_warm_mem_state_std_1 = np.std(average_gpu_warm_mem_state_1) / np.sqrt(len(average_gpu_warm_mem_state_1))
power_warm_mem_state_std_1 = np.std(average_power_warm_mem_state_1) / np.sqrt(len(average_power_warm_mem_state_1))
bw_warm_mem_state_std_1 = np.std(average_bw_warm_mem_state_1) / np.sqrt(len(average_bw_warm_mem_state_1))
energy_warm_mem_state_std_1 = np.std(average_energy_warm_mem_state_1) / np.sqrt(len(average_energy_warm_mem_state_1))

# Warm Disk State
ram_warm_disk_state_std_1 = np.std(average_ram_warm_disk_state_1) / np.sqrt(len(average_ram_warm_disk_state_1))
cpu_warm_disk_state_std_1 = np.std(average_cpu_warm_disk_state_1) / np.sqrt(len(average_cpu_warm_disk_state_1))
gpu_warm_disk_state_std_1 = np.std(average_gpu_warm_disk_state_1) / np.sqrt(len(average_gpu_warm_disk_state_1))
power_warm_disk_state_std_1 = np.std(average_power_warm_disk_state_1) / np.sqrt(len(average_power_warm_disk_state_1))
bw_warm_disk_state_std_1 = np.std(average_bw_warm_disk_state_1) / np.sqrt(len(average_bw_warm_disk_state_1))
energy_warm_disk_state_std_1 = np.std(average_energy_warm_disk_state_1) / np.sqrt(len(average_energy_warm_disk_state_1))

# Warm CPU State
ram_warm_cpu_state_std_1 = np.std(average_ram_warm_cpu_state_1) / np.sqrt(len(average_ram_warm_cpu_state_1))
cpu_warm_cpu_state_std_1 = np.std(average_cpu_warm_cpu_state_1) / np.sqrt(len(average_cpu_warm_cpu_state_1))
gpu_warm_cpu_state_std_1 = np.std(average_gpu_warm_cpu_state_1) / np.sqrt(len(average_gpu_warm_cpu_state_1))
power_warm_cpu_state_std_1 = np.std(average_power_warm_cpu_state_1) / np.sqrt(len(average_power_warm_cpu_state_1))
bw_warm_cpu_state_std_1 = np.std(average_bw_warm_cpu_state_1) / np.sqrt(len(average_bw_warm_cpu_state_1))
energy_warm_cpu_state_std_1 = np.std(average_energy_warm_cpu_state_1) / np.sqrt(len(average_energy_warm_cpu_state_1))

# Active State
ram_active_state_std_1 = np.std(average_ram_active_state_1) / np.sqrt(len(average_ram_active_state_1))
cpu_active_state_std_1 = np.std(average_cpu_active_state_1) / np.sqrt(len(average_cpu_active_state_1))
gpu_active_state_std_1 = np.std(average_gpu_active_state_1) / np.sqrt(len(average_gpu_active_state_1))
power_active_state_std_1 = np.std(average_power_active_state_1) / np.sqrt(len(average_power_active_state_1))
bw_active_state_std_1 = np.std(average_bw_active_state_1) / np.sqrt(len(average_bw_active_state_1))
energy_active_state_std_1 = np.std(average_energy_active_state_1) / np.sqrt(len(average_energy_active_state_1))

# Cold State
ram_cold_state_std_1 = np.std(average_ram_cold_state_1) / np.sqrt(len(average_ram_cold_state_1))
cpu_cold_state_std_1 = np.std(average_cpu_cold_state_1) / np.sqrt(len(average_cpu_cold_state_1))
gpu_cold_state_std_1 = np.std(average_gpu_cold_state_1) / np.sqrt(len(average_gpu_cold_state_1))
power_cold_state_std_1 = np.std(average_power_cold_state_1) / np.sqrt(len(average_power_cold_state_1))
bw_cold_state_std_1 = np.std(average_bw_cold_state_1) / np.sqrt(len(average_bw_cold_state_1))
energy_cold_state_std_1 = np.std(average_energy_cold_state_1) / np.sqrt(len(average_energy_cold_state_1))

# %%
#STATES
# Calculate the average
ram_null_state_mean_2 = np.mean(average_ram_null_state_2)
cpu_null_state_mean_2 = np.mean(average_cpu_null_state_2) 
gpu_null_state_mean_2 = np.mean(average_gpu_null_state_2)
power_null_state_mean_2 = np.mean(average_power_null_state_2)
bw_null_state_mean_2 = np.mean(average_bw_null_state_2)
energy_null_state_mean_2 = np.mean(average_energy_null_state_2)


ram_warm_mem_state_mean_2 = np.mean(average_ram_warm_mem_state_2)
cpu_warm_mem_state_mean_2 = np.mean(average_cpu_warm_mem_state_2)
gpu_warm_mem_state_mean_2 = np.mean(average_gpu_warm_mem_state_2)
power_warm_mem_state_mean_2 = np.mean(average_power_warm_mem_state_2) 
bw_warm_mem_state_mean_2 = np.mean(average_bw_warm_mem_state_2)
energy_warm_mem_state_mean_2 = np.mean(average_energy_warm_mem_state_2)


ram_warm_disk_state_mean_2 = np.mean(average_ram_warm_disk_state_2)
cpu_warm_disk_state_mean_2 = np.mean(average_cpu_warm_disk_state_2) 
gpu_warm_disk_state_mean_2 = np.mean(average_gpu_warm_disk_state_2)
power_warm_disk_state_mean_2 = np.mean(average_power_warm_disk_state_2)
bw_warm_disk_state_mean_2 = np.mean(average_bw_warm_disk_state_2)
energy_warm_disk_state_mean_2 = np.mean(average_energy_warm_disk_state_2)


ram_warm_cpu_state_mean_2 = np.mean(average_ram_warm_cpu_state_2) 
cpu_warm_cpu_state_mean_2 = np.mean(average_cpu_warm_cpu_state_2)
gpu_warm_cpu_state_mean_2 = np.mean(average_gpu_warm_cpu_state_2)
power_warm_cpu_state_mean_2 = np.mean(average_power_warm_cpu_state_2)
bw_warm_cpu_state_mean_2 = np.mean(average_bw_warm_cpu_state_2)
energy_warm_cpu_state_mean_2 = np.mean(average_energy_warm_cpu_state_2)


ram_active_state_mean_2 = np.mean(average_ram_active_state_2)
cpu_active_state_mean_2 = np.mean(average_cpu_active_state_2)
gpu_active_state_mean_2 = np.mean(average_gpu_active_state_2)
power_active_state_mean_2 = np.mean(average_power_active_state_2)
bw_active_state_mean_2 = np.mean(average_bw_active_state_2)
energy_active_state_mean_2 = np.mean(average_energy_active_state_2)


ram_cold_state_mean_2 = np.mean(average_ram_cold_state_2)
cpu_cold_state_mean_2 = np.mean(average_cpu_cold_state_2)
gpu_cold_state_mean_2 = np.mean(average_gpu_cold_state_2)
power_cold_state_mean_2 = np.mean(average_power_cold_state_2)
bw_cold_state_mean_2 = np.mean(average_bw_cold_state_2)
energy_cold_state_mean_2 = np.mean(average_energy_cold_state_2)


# Calculate the standard deviation


# Null State
ram_null_state_std_2 = np.std(average_ram_null_state_2) / np.sqrt(len(average_ram_null_state_2))
cpu_null_state_std_2 = np.std(average_cpu_null_state_2) / np.sqrt(len(average_cpu_null_state_2))
gpu_null_state_std_2 = np.std(average_gpu_null_state_2) / np.sqrt(len(average_gpu_null_state_2))
power_null_state_std_2 = np.std(average_power_null_state_2) / np.sqrt(len(average_power_null_state_2))
bw_null_state_std_2 = np.std(average_bw_null_state_2) / np.sqrt(len(average_bw_null_state_2))
energy_null_state_std_2 = np.std(average_energy_null_state_2) / np.sqrt(len(average_energy_null_state_2))

# Warm Memory State
ram_warm_mem_state_std_2 = np.std(average_ram_warm_mem_state_2) / np.sqrt(len(average_ram_warm_mem_state_2))
cpu_warm_mem_state_std_2 = np.std(average_cpu_warm_mem_state_2) / np.sqrt(len(average_cpu_warm_mem_state_2))
gpu_warm_mem_state_std_2 = np.std(average_gpu_warm_mem_state_2) / np.sqrt(len(average_gpu_warm_mem_state_2))
power_warm_mem_state_std_2 = np.std(average_power_warm_mem_state_2) / np.sqrt(len(average_power_warm_mem_state_2))
bw_warm_mem_state_std_2 = np.std(average_bw_warm_mem_state_2) / np.sqrt(len(average_bw_warm_mem_state_2))
energy_warm_mem_state_std_2 = np.std(average_energy_warm_mem_state_2) / np.sqrt(len(average_energy_warm_mem_state_2))

# Warm Disk State
ram_warm_disk_state_std_2 = np.std(average_ram_warm_disk_state_2) / np.sqrt(len(average_ram_warm_disk_state_2))
cpu_warm_disk_state_std_2 = np.std(average_cpu_warm_disk_state_2) / np.sqrt(len(average_cpu_warm_disk_state_2))
gpu_warm_disk_state_std_2 = np.std(average_gpu_warm_disk_state_2) / np.sqrt(len(average_gpu_warm_disk_state_2))
power_warm_disk_state_std_2 = np.std(average_power_warm_disk_state_2) / np.sqrt(len(average_power_warm_disk_state_2))
bw_warm_disk_state_std_2 = np.std(average_bw_warm_disk_state_2) / np.sqrt(len(average_bw_warm_disk_state_2))
energy_warm_disk_state_std_2 = np.std(average_energy_warm_disk_state_2) / np.sqrt(len(average_energy_warm_disk_state_2))

# Warm CPU State
ram_warm_cpu_state_std_2 = np.std(average_ram_warm_cpu_state_2) / np.sqrt(len(average_ram_warm_cpu_state_2))
cpu_warm_cpu_state_std_2 = np.std(average_cpu_warm_cpu_state_2) / np.sqrt(len(average_cpu_warm_cpu_state_2))
gpu_warm_cpu_state_std_2 = np.std(average_gpu_warm_cpu_state_2) / np.sqrt(len(average_gpu_warm_cpu_state_2))
power_warm_cpu_state_std_2 = np.std(average_power_warm_cpu_state_2) / np.sqrt(len(average_power_warm_cpu_state_2))
bw_warm_cpu_state_std_2 = np.std(average_bw_warm_cpu_state_2) / np.sqrt(len(average_bw_warm_cpu_state_2))
energy_warm_cpu_state_std_2 = np.std(average_energy_warm_cpu_state_2) / np.sqrt(len(average_energy_warm_cpu_state_2))

# Active State
ram_active_state_std_2 = np.std(average_ram_active_state_2) / np.sqrt(len(average_ram_active_state_2))
cpu_active_state_std_2 = np.std(average_cpu_active_state_2) / np.sqrt(len(average_cpu_active_state_2))
gpu_active_state_std_2 = np.std(average_gpu_active_state_2) / np.sqrt(len(average_gpu_active_state_2))
power_active_state_std_2 = np.std(average_power_active_state_2) / np.sqrt(len(average_power_active_state_2))
bw_active_state_std_2 = np.std(average_bw_active_state_2) / np.sqrt(len(average_bw_active_state_2))
energy_active_state_std_2 = np.std(average_energy_active_state_2) / np.sqrt(len(average_energy_active_state_2))

# Cold State
ram_cold_state_std_2 = np.std(average_ram_cold_state_2) / np.sqrt(len(average_ram_cold_state_2))
cpu_cold_state_std_2 = np.std(average_cpu_cold_state_2) / np.sqrt(len(average_cpu_cold_state_2))
gpu_cold_state_std_2 = np.std(average_gpu_cold_state_2) / np.sqrt(len(average_gpu_cold_state_2))
power_cold_state_std_2 = np.std(average_power_cold_state_2) / np.sqrt(len(average_power_cold_state_2))
bw_cold_state_std_2 = np.std(average_bw_cold_state_2) / np.sqrt(len(average_bw_cold_state_2))
energy_cold_state_std_2 = np.std(average_energy_cold_state_2) / np.sqrt(len(average_energy_cold_state_2))

# %%
print(energy_active_state_mean)
print(energy_active_state_mean_1)
print(energy_active_state_mean_2)

print("====")
print(energy_active_state_std)
print(energy_active_state_std_1)
print(energy_active_state_std_2)
# Out:
# 9482.4
# 10159.2
# 9424.8
# ====
# 159.24863578693538
# 104.53646253819763
# 135.62017549022713

# %%
import numpy as np
import matplotlib.pyplot as plt

data = [6264.0, 7668.0, 7092.0]
data_1 = [6696.0, 7920.0, 8712.0]
data_2 = [7092.0, 7992.0, 8892.0]

state = ["1 Request", "2 Request", "3 Request"]
fig, ax = plt.subplots(figsize=(10, 6))

# Plot for data_1
container_bars = ax.bar(x_pos - 0.2, data, width=0.2, align='center', alpha=1, color='lightblue', edgecolor='blue', capsize=8, label='Multiple Container')

# Plot for data_2
process_bars = ax.bar(x_pos, data_1, width=0.2, align='center', alpha=1, color='lightgreen', edgecolor='green', capsize=8, label='Multiple Process')

# Plot for data (pod at the end)
pod_bars = ax.bar(x_pos + 0.2, data_2, width=0.2, align='center', alpha=1, color='lightcoral', edgecolor='red', capsize=8, label='Multiple Pod')

ax.set_ylabel("Energy at active state (J)", fontsize=15)
ax.set_xticks(x_pos)
ax.set_xticklabels(state, rotation=15, fontsize=12)
ax.legend()
ax.tick_params(axis='both', which='major', labelsize=12)
ax.set_ylim(0, 13000)

plt.title("Comparison of Energy at Active State", fontsize=16)
plt.tight_layout()
plt.savefig('../pdf/power-states-comparison.pdf', bbox_inches='tight')
plt.show()

# %%
# Energy at active state
import numpy as np
import matplotlib.pyplot as plt

data = [9518.4, 9295.2, 9417.6, 9482.4, 10159.2, 9424.8]
error = [110.8893502551079, 134.08248207726464, 152.59923984083275, 159.24863578693538, 104.53646253819763, 135.62017549022713]

error_std = [value*z_value for value in error]
state = ["1-1-4", "1-2-2", "1-4-1", "2-1-2", "2-2-1", "4-1-1"]

fig1, ax1 = plot.subplots()
x_pos = x_pos = np.arange(len(state))
ax1.bar(x_pos, data, yerr=error_std, align='center', alpha=0.9, ecolor='red', capsize=12)
# ax1.set_title('Average power usage of states')
data_round = [round(x, 1) for x in data]
bars= ax1.bar(state, data_round, color="darkblue")
ax1.bar_label(bars, label_type='center',color="w", fontsize = 11)
ax1.set_ylabel("Energy (J)", fontsize = 15)
# ax1.set_xlabel("State ($S$)", fontsize = 15)
# ax1.set_xticks(rotation=15)
ax1.set_xticklabels(ax1.get_xticks(), rotation = 15)
# ax1.set_xticks(x_pos)
# ax1.set_yticks(fontsize = 13)
ax1.tick_params(axis='both', which='major', labelsize=20)
ax1.set_xticklabels(state, fontsize = 12)
ax1.set_ylim(0,13000)
plot.savefig('../pdf/power-states.pdf', bbox_inches='tight')
plot.show()
# Out:
# /tmp/ipykernel_190416/1908358153.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(ax1.get_xticks(), rotation = 15)
# /tmp/ipykernel_190416/1908358153.py:25: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(state, fontsize = 12)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Power in states
data = [power_null_state_mean, power_cold_state_mean,  power_warm_disk_state_mean, power_warm_cpu_state_mean, power_active_state_mean]
error = [power_null_state_std, power_cold_state_std,  power_warm_disk_state_std, power_warm_cpu_state_std, power_active_state_std]

data_1 = [power_null_state_mean_1, power_cold_state_mean_1,  power_warm_disk_state_mean_1, power_warm_cpu_state_mean_1, power_active_state_mean_1]
error_1 = [power_null_state_std_1, power_cold_state_std_1,  power_warm_disk_state_std_1, power_warm_cpu_state_std_1, power_active_state_std_1]

data_2 = [power_null_state_mean_2, power_cold_state_mean_2,  power_warm_disk_state_mean_2, power_warm_cpu_state_mean_2, power_active_state_mean_2]
error_2 = [power_null_state_std_2, power_cold_state_std_2,  power_warm_disk_state_std_2, power_warm_cpu_state_std_2, power_active_state_std_2]

state = ["Null", "Cold", "Warm Disk", "Warm CPU", "Active"]

error_std = [value * z_value for value in error]
error_1_std = [value * z_value for value in error_1]
error_2_std = [value * z_value for value in error_2]

# %%
fig1, ax1 = plot.subplots()
x_pos = x_pos = np.arange(len(state))
ax1.bar(x_pos, data, yerr=error_std, align='center', alpha=0.9, ecolor='red', capsize=12)
# ax1.set_title('Average power usage of states')
data_round = [round(x, 2) for x in data]
bars= ax1.bar(state, data_round, color="darkblue")
ax1.bar_label(bars, label_type='center',color="w", fontsize = 14)
ax1.set_ylabel("Power (W)", fontsize = 15)
# ax1.set_xlabel("State ($S$)", fontsize = 15)
# ax1.set_xticks(rotation=15)
ax1.set_xticklabels(ax1.get_xticks(), rotation = 15)
# ax1.set_xticks(x_pos)
# ax1.set_yticks(fontsize = 13)
ax1.tick_params(axis='both', which='major', labelsize=20)
ax1.set_xticklabels(state, fontsize = 12)
ax1.set_ylim(0,300)
plot.savefig('../pdf/power-states.pdf', bbox_inches='tight')
plot.show()
# Out:
# /tmp/ipykernel_3560423/987759022.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(ax1.get_xticks(), rotation = 15)
# /tmp/ipykernel_3560423/987759022.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(state, fontsize = 12)

# %%
fig1, ax1 = plot.subplots()
x_pos = x_pos = np.arange(len(state))
ax1.bar(x_pos, data_2, yerr=error_2_std, align='center', alpha=0.9, ecolor='red', capsize=12)
# ax1.set_title('Average power usage of states')
data_round = [round(x, 2) for x in data_2]
bars= ax1.bar(state, data_round, color="darkblue")
ax1.bar_label(bars, label_type='center',color="w", fontsize = 14)
ax1.set_ylabel("Power (W)", fontsize = 15)
# ax1.set_xlabel("State ($S$)", fontsize = 15)
# ax1.set_xticks(rotation=15)
ax1.set_xticklabels(ax1.get_xticks(), rotation = 15)
# ax1.set_xticks(x_pos)
# ax1.set_yticks(fontsize = 13)
ax1.tick_params(axis='both', which='major', labelsize=20)
ax1.set_xticklabels(state, fontsize = 12)
ax1.set_ylim(0,300)
plot.savefig('../pdf/power-states.pdf', bbox_inches='tight')
plot.show()
# Out:
# /tmp/ipykernel_3560423/3271888293.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(ax1.get_xticks(), rotation = 15)
# /tmp/ipykernel_3560423/3271888293.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(state, fontsize = 12)

# %%
fig1, ax1 = plot.subplots()
x_pos = x_pos = np.arange(len(state))
ax1.bar(x_pos, data, yerr=error_1_std, align='center', alpha=0.9, ecolor='red', capsize=12)
# ax1.set_title('Average power usage of states')
data_round = [round(x, 2) for x in data_1]
bars= ax1.bar(state, data_round, color="darkblue")
ax1.bar_label(bars, label_type='center',color="w", fontsize = 14)
ax1.set_ylabel("Power (W)", fontsize = 15)
# ax1.set_xlabel("State ($S$)", fontsize = 15)
# ax1.set_xticks(rotation=15)
ax1.set_xticklabels(ax1.get_xticks(), rotation = 15)
# ax1.set_xticks(x_pos)
# ax1.set_yticks(fontsize = 13)
ax1.tick_params(axis='both', which='major', labelsize=20)
ax1.set_xticklabels(state, fontsize = 12)
ax1.set_ylim(0,300)
plot.savefig('../pdf/power-states.pdf', bbox_inches='tight')
plot.show()
# Out:
# /tmp/ipykernel_3560423/880143228.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(ax1.get_xticks(), rotation = 15)
# /tmp/ipykernel_3560423/880143228.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(state, fontsize = 12)

# %%
import numpy as np
import matplotlib.pyplot as plt6

# Bandwidth in states
data = [bw_null_state_mean, bw_cold_state_mean,  bw_warm_disk_state_mean, bw_warm_cpu_state_mean, bw_active_state_mean]
error = [bw_null_state_std, bw_cold_state_std,  bw_warm_disk_state_std, bw_warm_cpu_state_std, bw_active_state_std]

data_1 = [bw_null_state_mean_1, bw_cold_state_mean_1,  bw_warm_disk_state_mean_1, bw_warm_cpu_state_mean_1, bw_active_state_mean_1]
error_1 = [bw_null_state_std_1, bw_cold_state_std_1,  bw_warm_disk_state_std_1, bw_warm_cpu_state_std_1, bw_active_state_std_1]

data_2 = [bw_null_state_mean_2, bw_cold_state_mean_2,  bw_warm_disk_state_mean_2, bw_warm_cpu_state_mean_2, bw_active_state_mean_2]
error_2 = [bw_null_state_std_2, bw_cold_state_std_2,  bw_warm_disk_state_std_2, bw_warm_cpu_state_std_2, bw_active_state_std_2]

state = ["Null", "Cold", "Warm Disk", "Warm CPU", "Active"]

error_std = [value*z_value for value in error]
error_1_std = [value*z_value for value in error_1]
error_2_std = [value*z_value for value in error_2]


data_abs = [round(abs(x)* (1024**4)/(1024), 2) for x in data]
data_1_abs = [round(abs(x)* (1024**4)/(1024), 2) for x in data_1]
data_2_abs = [round(abs(x)* (1024**4)/(1024), 2) for x in data_2]

# %%
fig1, ax1 = plot.subplots()
x_pos = x_pos = np.arange(len(state))
ax1.bar(x_pos, data_abs, yerr=error_std, align='center', alpha=0.9, ecolor='red', capsize=12)
# ax1.set_title('RAM of states')
data_round = [round(x, 2) for x in data_abs]
bars= ax1.bar(state, data_round, color="darkblue")
ax1.bar_label(bars, label_type='center',color="w", fontsize = 14)

ax1.set_ylabel("BW (Kbps)", fontsize=15)
ax1.set_xticklabels(ax1.get_xticks(), rotation=15)
ax1.tick_params(axis='both', which='major', labelsize=20)
ax1.set_xticklabels(state, fontsize=12)
ax1.set_ylim(0, 250)
plot.savefig('../pdf/bw-states.pdf', bbox_inches='tight')
plot.show()
# Out:
# /tmp/ipykernel_3560423/122686712.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(ax1.get_xticks(), rotation=15)
# /tmp/ipykernel_3560423/122686712.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(state, fontsize=12)

# %%
fig1, ax1 = plot.subplots()
x_pos = x_pos = np.arange(len(state))
ax1.bar(x_pos, data_2_abs, yerr=error_2_std, align='center', alpha=0.9, ecolor='red', capsize=12)
# ax1.set_title('RAM of states')
data_round = [round(x, 2) for x in data_2_abs]
bars= ax1.bar(state, data_round, color="darkblue")
ax1.bar_label(bars, label_type='center',color="w", fontsize = 14)

ax1.set_ylabel("BW (Kbps)", fontsize=15)
ax1.set_xticklabels(ax1.get_xticks(), rotation=15)
ax1.tick_params(axis='both', which='major', labelsize=20)
ax1.set_xticklabels(state, fontsize=12)
ax1.set_ylim(0, 250)
plot.savefig('../pdf/bw-states.pdf', bbox_inches='tight')
plot.show()
# Out:
# /tmp/ipykernel_3560423/2708681485.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(ax1.get_xticks(), rotation=15)
# /tmp/ipykernel_3560423/2708681485.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(state, fontsize=12)

# %%
fig1, ax1 = plot.subplots()
x_pos = x_pos = np.arange(len(state))
ax1.bar(x_pos, data_1_abs, yerr=error_1_std, align='center', alpha=0.9, ecolor='red', capsize=12)
# ax1.set_title('RAM of states')
data_round = [round(x, 2) for x in data_1_abs]
bars= ax1.bar(state, data_round, color="darkblue")
ax1.bar_label(bars, label_type='center',color="w", fontsize = 14)

ax1.set_ylabel("BW (Kbps)", fontsize=15)
ax1.set_xticklabels(ax1.get_xticks(), rotation=15)
ax1.tick_params(axis='both', which='major', labelsize=20)
ax1.set_xticklabels(state, fontsize=12)
ax1.set_ylim(0, 250)
plot.savefig('../pdf/bw-states.pdf', bbox_inches='tight')
plot.show()
# Out:
# /tmp/ipykernel_3560423/1977654458.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(ax1.get_xticks(), rotation=15)
# /tmp/ipykernel_3560423/1977654458.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(state, fontsize=12)

# %%
# Energy in states
data = [energy_null_state_mean, energy_cold_state_mean, energy_warm_disk_state_mean, energy_warm_cpu_state_mean, energy_active_state_mean]
error = [energy_null_state_std, energy_cold_state_std, energy_warm_disk_state_std, energy_warm_cpu_state_std, energy_active_state_std]

data_1 = [energy_null_state_mean_1, energy_cold_state_mean_1, energy_warm_disk_state_mean_1, energy_warm_cpu_state_mean_1, energy_active_state_mean_1]
error_1 = [energy_null_state_std_1, energy_cold_state_std_1, energy_warm_disk_state_std_1, energy_warm_cpu_state_std_1, energy_active_state_std_1]

data_2 = [energy_null_state_mean_2, energy_cold_state_mean_2, energy_warm_disk_state_mean_2, energy_warm_cpu_state_mean_2, energy_active_state_mean_2]
error_2 = [energy_null_state_std_2, energy_cold_state_std_2, energy_warm_disk_state_std_2, energy_warm_cpu_state_std_2, energy_active_state_std_2]

state = ["Null", "Cold", "Warm Disk", "Warm CPU", "Active"]

fig, ax = plt.subplots(figsize=(10, 6))

# Plot for data
x_pos = np.arange(len(state))
ax.bar(x_pos - 0.2, data, yerr=error, width=0.2, align='center', alpha=0.9, ecolor='red', capsize=12, label='Multiple Container')

# Plot for data_1
ax.bar(x_pos, data_1, yerr=error_1, width=0.2, align='center', alpha=0.9, ecolor='blue', capsize=12, label='Multiple Process')

# Plot for data_2
ax.bar(x_pos + 0.2, data_2, yerr=error_2, width=0.2, align='center', alpha=0.9, ecolor='green', capsize=12, label='Multiple Pod')

ax.set_ylabel("Energy (J)", fontsize=15)
ax.set_xticks(x_pos)
ax.set_xticklabels(state, rotation=15, fontsize=12)
ax.legend()
ax.tick_params(axis='both', which='major', labelsize=12)
ax.set_ylim(0, 9000)

plt.savefig('../pdf/bw-states-comparison.pdf', bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# RAM in states
data = [ram_null_state_mean, ram_cold_state_mean,  ram_warm_disk_state_mean, ram_warm_cpu_state_mean, ram_active_state_mean]
error = [ram_null_state_std, ram_cold_state_std,  ram_warm_disk_state_std, ram_warm_cpu_state_std, ram_active_state_std]

data_1 = [ram_null_state_mean_1, ram_cold_state_mean_1,  ram_warm_disk_state_mean_1, ram_warm_cpu_state_mean_1, ram_active_state_mean_1]
error_1 = [ram_null_state_std_1, ram_cold_state_std_1,  ram_warm_disk_state_std_1, ram_warm_cpu_state_std_1, ram_active_state_std_1]

data_2 = [ram_null_state_mean_2, ram_cold_state_mean_2,  ram_warm_disk_state_mean_2, ram_warm_cpu_state_mean_2, ram_active_state_mean_2]
error_2 = [ram_null_state_std_2, ram_cold_state_std_2,  ram_warm_disk_state_std_2, ram_warm_cpu_state_std_2, ram_active_state_std_2]

state = ["Null", "Cold", "Warm Disk", "Warm CPU", "Active"]

error_std = [value*z_value for value in error]
error_1_std = [value*z_value for value in error_1]
error_2_std = [value*z_value for value in error_2]

# %%
fig1, ax1 = plot.subplots()
x_pos = x_pos = np.arange(len(state))
ax1.bar(x_pos, data, yerr=error_std, align='center', alpha=0.9, ecolor='red', capsize=12)
# ax1.set_title('RAM of states')
data_round = [round(x, 2) for x in data]
bars= ax1.bar(state, data_round, color="darkblue")
ax1.bar_label(bars, label_type='center',color="w", fontsize = 14)
ax1.set_ylabel("RAM (%)",  fontsize = 15)
# ax1.set_xlabel("State ($S$)",  fontsize = 15)
ax1.set_xticks(x_pos)
ax1.set_xticklabels(state, rotation = 15)
# ax1.set_xticklabels(ax1.get_xticks(), )

ax1.set_ylim(0,30)
ax1.tick_params(axis='both', which='major', labelsize=12)
# ax1.tick_params(axis='both', which='minor', labelsize=15)
plot.savefig('../pdf/RAM-states.pdf', bbox_inches='tight')
plot.show()

# %%
fig1, ax1 = plot.subplots()
x_pos = x_pos = np.arange(len(state))
ax1.bar(x_pos, data_2, yerr=error_2_std, align='center', alpha=0.9, ecolor='red', capsize=12)
# ax1.set_title('RAM of states')
data_round = [round(x, 2) for x in data_2]
bars= ax1.bar(state, data_round, color="darkblue")
ax1.bar_label(bars, label_type='center',color="w", fontsize = 14)
ax1.set_ylabel("RAM (%)",  fontsize = 15)
# ax1.set_xlabel("State ($S$)",  fontsize = 15)
ax1.set_xticks(x_pos)
ax1.set_xticklabels(state, rotation = 15)
# ax1.set_xticklabels(ax1.get_xticks(), )

ax1.set_ylim(0,30)
ax1.tick_params(axis='both', which='major', labelsize=12)
# ax1.tick_params(axis='both', which='minor', labelsize=15)
plot.savefig('../pdf/RAM-states.pdf', bbox_inches='tight')
plot.show()

# %%
fig1, ax1 = plot.subplots()
x_pos = x_pos = np.arange(len(state))
ax1.bar(x_pos, data_1, yerr=error_1_std, align='center', alpha=0.9, ecolor='red', capsize=12)
# ax1.set_title('RAM of states')
data_round = [round(x, 2) for x in data_1]
bars= ax1.bar(state, data_round, color="darkblue")
ax1.bar_label(bars, label_type='center',color="w", fontsize = 14)
ax1.set_ylabel("RAM (%)",  fontsize = 15)
# ax1.set_xlabel("State ($S$)",  fontsize = 15)
ax1.set_xticks(x_pos)
ax1.set_xticklabels(state, rotation = 15)
# ax1.set_xticklabels(ax1.get_xticks(), )

ax1.set_ylim(0,30)
ax1.tick_params(axis='both', which='major', labelsize=12)
# ax1.tick_params(axis='both', which='minor', labelsize=15)
plot.savefig('../pdf/RAM-states.pdf', bbox_inches='tight')
plot.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# CPU in states
data = [cpu_null_state_mean, cpu_cold_state_mean,  cpu_warm_disk_state_mean, cpu_warm_cpu_state_mean, cpu_active_state_mean]
error = [cpu_null_state_std, cpu_cold_state_std,  cpu_warm_disk_state_std, cpu_warm_cpu_state_std, cpu_active_state_std]

data_1 = [cpu_null_state_mean_1, cpu_cold_state_mean_1,  cpu_warm_disk_state_mean_1, cpu_warm_cpu_state_mean_1, cpu_active_state_mean_1]
error_1 = [cpu_null_state_std_1, cpu_cold_state_std_1,  cpu_warm_disk_state_std_1, cpu_warm_cpu_state_std_1, cpu_active_state_std_1]

data_2 = [cpu_null_state_mean_2, cpu_cold_state_mean_2,  cpu_warm_disk_state_mean_2, cpu_warm_cpu_state_mean_2, cpu_active_state_mean_2]
error_2 = [cpu_null_state_std_2, cpu_cold_state_std_2,  cpu_warm_disk_state_std_2, cpu_warm_cpu_state_std_2, cpu_active_state_std_2]

state = ["Null", "Cold", "Warm Disk", "Warm CPU", "Active"]

error_std = [value*z_value for value in error]
error_1_std = [value*z_value for value in error_1]
error_2_std = [value*z_value for value in error_2]

# %%
fig1, ax1 = plot.subplots()
x_pos = x_pos = np.arange(len(state))
ax1.bar(x_pos, data, yerr=error_std, align='center', alpha=0.9, ecolor='red', capsize=12)
# ax1.set_title('CPU of states')
data_round = [round(x, 2) for x in data]
bars= ax1.bar(state, data_round, color="darkblue")
ax1.bar_label(bars, label_type='center',color="w", fontsize = 14)
# ax1.set_xlabel("State ($S$)",  fontsize = 15)
ax1.set_ylabel("CPU (%)",  fontsize = 15)
ax1.set_xticks(x_pos)
ax1.set_xticklabels(state,  rotation = 15)
ax1.set_ylim(0,40)
ax1.tick_params(axis='both', which='major', labelsize=12)
plot.savefig('../pdf/CPU-states.pdf', bbox_inches='tight')
plot.show()

# %%
fig1, ax1 = plot.subplots()
x_pos = x_pos = np.arange(len(state))
ax1.bar(x_pos, data_2, yerr=error_2_std, align='center', alpha=0.9, ecolor='red', capsize=12)
# ax1.set_title('CPU of states')
data_round = [round(x, 2) for x in data_2]
bars= ax1.bar(state, data_round, color="darkblue")
ax1.bar_label(bars, label_type='center',color="w", fontsize = 14)
# ax1.set_xlabel("State ($S$)",  fontsize = 15)
ax1.set_ylabel("CPU (%)",  fontsize = 15)
ax1.set_xticks(x_pos)
ax1.set_xticklabels(state,  rotation = 15)
ax1.set_ylim(0,40)
ax1.tick_params(axis='both', which='major', labelsize=12)
plot.savefig('../pdf/CPU-states.pdf', bbox_inches='tight')
plot.show()

# %%
fig1, ax1 = plot.subplots()
x_pos = x_pos = np.arange(len(state))
ax1.bar(x_pos, data_1, yerr=error_1_std, align='center', alpha=0.9, ecolor='red', capsize=12)
# ax1.set_title('CPU of states')
data_round = [round(x, 2) for x in data_1]
bars= ax1.bar(state, data_round, color="darkblue")
ax1.bar_label(bars, label_type='center',color="w", fontsize = 14)
# ax1.set_xlabel("State ($S$)",  fontsize = 15)
ax1.set_ylabel("CPU (%)",  fontsize = 15)
ax1.set_xticks(x_pos)
ax1.set_xticklabels(state,  rotation = 15)
ax1.set_ylim(0,40)
ax1.tick_params(axis='both', which='major', labelsize=12)
plot.savefig('../pdf/CPU-states.pdf', bbox_inches='tight')
plot.show()

# %%
#GPU in states
data = [gpu_null_state_mean, gpu_cold_state_mean,  gpu_warm_disk_state_mean, gpu_warm_cpu_state_mean,
        gpu_active_state_mean]
error = [gpu_null_state_std, gpu_cold_state_std,  gpu_warm_disk_state_std, gpu_warm_cpu_state_std,
        gpu_active_state_std]
# state = ["$S_n$", "$S_c$", "$S_{wd}$", "$S_{wc}$", "$S_{wm}$",  "$S_a$"]
state = ["Null", "Cold", "Warm Disk", "Warm CPU", "Active"]

fig1, ax1 = plot.subplots()
x_pos = x_pos = np.arange(len(state))
ax1.bar(x_pos, data, yerr=error, align='center', alpha=0.9, ecolor='red', capsize=10)
# ax1.set_title('CPU of states')
data_round = [round(x, 2) for x in data]
bars= ax1.bar(state, data_round, color="darkblue")
ax1.bar_label(bars, label_type='center',color="w", fontsize = 14)
# ax1.set_xlabel("State ($S$)")
ax1.set_ylabel("GPU (%)")
ax1.set_xticks(x_pos)
ax1.set_ylim(0,100)
ax1.set_xticklabels(state,  rotation = 15)
ax1.tick_params(axis='both', which='major', labelsize=12)
plot.savefig('../pdf/GPU-states.pdf', bbox_inches='tight')
plot.show()

# %%
#PROCESS
# Calculate the average
ram_null_to_cold_process_mean = np.mean(average_ram_null_to_cold_process)
cpu_null_to_cold_process_mean = np.mean(average_cpu_null_to_cold_process)
power_null_to_cold_process_mean = np.mean(average_power_null_to_cold_process)
energy_null_to_cold_process_mean = np.mean(average_energy_null_to_cold_process)
bw_null_to_cold_process_mean = np.mean(average_bw_null_to_cold_process)

ram_warm_disk_to_warm_cpu_process_mean = np.mean(average_ram_warm_disk_to_warm_cpu_process)
cpu_warm_disk_to_warm_cpu_process_mean = np.mean(average_cpu_warm_disk_to_warm_cpu_process)
power_warm_disk_to_warm_cpu_process_mean = np.mean(average_power_warm_disk_to_warm_cpu_process)
energy_warm_disk_to_warm_cpu_process_mean = np.mean(average_energy_warm_disk_to_warm_cpu_process)
bw_warm_disk_to_warm_cpu_process_mean = np.mean(average_bw_warm_disk_to_warm_cpu_process)



ram_warm_cpu_to_warm_disk_process_mean = np.mean(average_ram_warm_cpu_to_warm_disk_process)
cpu_warm_cpu_to_warm_disk_process_mean = np.mean(average_cpu_warm_cpu_to_warm_disk_process)
power_warm_cpu_to_warm_disk_process_mean = np.mean(average_power_warm_cpu_to_warm_disk_process)
energy_warm_cpu_to_warm_disk_process_mean = np.mean(average_energy_warm_cpu_to_warm_disk_process)
bw_warm_cpu_to_warm_disk_process_mean = np.mean(average_bw_warm_cpu_to_warm_disk_process)

# ram_warm_mem_to_warm_disk_process_mean = np.mean(average_ram_warm_mem_to_warm_disk_process)
# cpu_warm_mem_to_warm_disk_process_mean = np.mean(average_cpu_warm_mem_to_warm_disk_process)
# power_warm_mem_to_warm_disk_process_mean = np.mean(average_power_warm_mem_to_warm_disk_process)
# energy_warm_mem_to_warm_disk_process_mean = np.mean(average_energy_warm_mem_to_warm_disk_process)
# bw_warm_mem_to_warm_disk_process_mean = np.mean(average_bw_warm_mem_to_warm_disk_process)

# ram_cold_to_warm_disk_process_mean = np.mean(average_ram_cold_to_warm_disk_process)
# cpu_cold_to_warm_disk_process_mean = np.mean(average_cpu_cold_to_warm_disk_process)
# power_cold_to_warm_disk_process_mean = np.mean(average_power_cold_to_warm_disk_process)
# energy_cold_to_warm_disk_process_mean = np.mean(average_energy_cold_to_warm_disk_process)
# bw_cold_to_warm_disk_process_mean = np.mean(average_bw_cold_to_warm_disk_process)

ram_active_to_warm_disk_process_mean = np.mean(average_ram_active_to_warm_disk_process)
cpu_active_to_warm_disk_process_mean = np.mean(average_cpu_active_to_warm_disk_process)
power_active_to_warm_disk_process_mean = np.mean(average_power_active_to_warm_disk_process)
energy_active_to_warm_disk_process_mean = np.mean(average_energy_active_to_warm_disk_process)
bw_active_to_warm_disk_process_mean = np.mean(average_bw_active_to_warm_disk_process)

# ram_warm_disk_to_cold_process_mean = np.mean(average_ram_warm_disk_to_cold_process)
# cpu_warm_disk_to_cold_process_mean = np.mean(average_cpu_warm_disk_to_cold_process)
# power_warm_disk_to_cold_process_mean = np.mean(average_power_warm_disk_to_cold_process)
# bw_warm_disk_to_cold_process_mean = np.mean(average_bw_warm_disk_to_cold_process)

ram_cold_to_null_process_mean = np.mean(average_ram_cold_to_null_process)
cpu_cold_to_null_process_mean = np.mean(average_cpu_cold_to_null_process)
power_cold_to_null_process_mean = np.mean(average_power_cold_to_null_process)
energy_cold_to_null_process_mean = np.mean(average_energy_cold_to_null_process)
bw_cold_to_null_process_mean = np.mean(average_bw_cold_to_null_process)

# Calculate the standard deviation
ram_null_to_cold_process_std = np.std(average_ram_null_to_cold_process)
cpu_null_to_cold_process_std = np.std(average_cpu_null_to_cold_process)
power_null_to_cold_process_std = np.std(average_power_null_to_cold_process)
energy_null_to_cold_process_std = np.std(average_energy_null_to_cold_process)
bw_null_to_cold_process_std = np.std(average_bw_null_to_cold_process)

ram_warm_disk_to_warm_cpu_process_std = np.std(average_ram_warm_disk_to_warm_cpu_process)
cpu_warm_disk_to_warm_cpu_process_std = np.std(average_cpu_warm_disk_to_warm_cpu_process)
power_warm_disk_to_warm_cpu_process_std = np.std(average_power_warm_disk_to_warm_cpu_process)
energy_warm_disk_to_warm_cpu_process_std = np.std(average_energy_warm_disk_to_warm_cpu_process)
bw_warm_disk_to_warm_cpu_process_std = np.std(average_bw_warm_disk_to_warm_cpu_process)

ram_warm_cpu_to_warm_disk_process_std = np.std(average_ram_warm_cpu_to_warm_disk_process)
cpu_warm_cpu_to_warm_disk_process_std = np.std(average_cpu_warm_cpu_to_warm_disk_process)
power_warm_cpu_to_warm_disk_process_std = np.std(average_power_warm_cpu_to_warm_disk_process)
energy_warm_cpu_to_warm_disk_process_std = np.std(average_energy_warm_cpu_to_warm_disk_process)
bw_warm_cpu_to_warm_disk_process_std = np.std(average_bw_warm_cpu_to_warm_disk_process)

# ram_warm_mem_to_warm_disk_process_std = np.std(average_ram_warm_mem_to_warm_disk_process)
# cpu_warm_mem_to_warm_disk_process_std = np.std(average_cpu_warm_mem_to_warm_disk_process)
# power_warm_mem_to_warm_disk_process_std = np.std(average_power_warm_mem_to_warm_disk_process)
# energy_warm_mem_to_warm_disk_process_std = np.std(average_energy_warm_mem_to_warm_disk_process)
# # bw_warm_mem_to_warm_disk_process_std = np.std(average_bw_warm_mem_to_warm_disk_process)


# ram_cold_to_warm_disk_process_std = np.std(average_ram_cold_to_warm_disk_process)
# cpu_cold_to_warm_disk_process_std = np.std(average_cpu_cold_to_warm_disk_process)
# power_cold_to_warm_disk_process_std = np.std(average_power_cold_to_warm_disk_process)
# energy_cold_to_warm_disk_process_std = np.std(average_energy_cold_to_warm_disk_process)
# bw_cold_to_warm_disk_process_std = np.std(average_bw_cold_to_warm_disk_process)

ram_active_to_warm_disk_process_std = np.std(average_ram_active_to_warm_disk_process)
cpu_active_to_warm_disk_process_std = np.std(average_cpu_active_to_warm_disk_process)
power_active_to_warm_disk_process_std = np.std(average_power_active_to_warm_disk_process)
energy_active_to_warm_disk_process_std = np.std(average_energy_active_to_warm_disk_process)
bw_active_to_warm_disk_process_std = np.std(average_bw_active_to_warm_disk_process)

# ram_warm_disk_to_cold_process_std = np.std(average_ram_warm_disk_to_cold_process)
# cpu_warm_disk_to_cold_process_std = np.std(average_cpu_warm_disk_to_cold_process)
# power_warm_disk_to_cold_process_std = np.std(average_power_warm_disk_to_cold_process)
# bw_warm_disk_to_cold_process_std = np.std(average_bw_warm_disk_to_cold_process)

ram_cold_to_null_process_std = np.std(average_ram_cold_to_null_process)
cpu_cold_to_null_process_std = np.std(average_cpu_cold_to_null_process)
power_cold_to_null_process_std = np.std(average_power_cold_to_null_process)
energy_cold_to_null_process_std = np.std(average_energy_cold_to_null_process)
bw_cold_to_null_process_std = np.std(average_bw_cold_to_null_process)

# %%
# Calculate the average
# Calculate the average
ram_null_to_cold_process_mean_1 = np.mean(average_ram_null_to_cold_process_1)
cpu_null_to_cold_process_mean_1 = np.mean(average_cpu_null_to_cold_process_1)
power_null_to_cold_process_mean_1 = np.mean(average_power_null_to_cold_process_1)
energy_null_to_cold_process_mean_1 = np.mean(average_energy_null_to_cold_process_1)
bw_null_to_cold_process_mean_1 = np.mean(average_bw_null_to_cold_process_1)

ram_warm_disk_to_warm_cpu_process_mean_1 = np.mean(average_ram_warm_disk_to_warm_cpu_process_1)
cpu_warm_disk_to_warm_cpu_process_mean_1 = np.mean(average_cpu_warm_disk_to_warm_cpu_process_1)
power_warm_disk_to_warm_cpu_process_mean_1 = np.mean(average_power_warm_disk_to_warm_cpu_process_1)
energy_warm_disk_to_warm_cpu_process_mean_1 = np.mean(average_energy_warm_disk_to_warm_cpu_process_1)
bw_warm_disk_to_warm_cpu_process_mean_1 = np.mean(average_bw_warm_disk_to_warm_cpu_process_1)

ram_warm_cpu_to_warm_disk_process_mean_1 = np.mean(average_ram_warm_cpu_to_warm_disk_process_1)
cpu_warm_cpu_to_warm_disk_process_mean_1 = np.mean(average_cpu_warm_cpu_to_warm_disk_process_1)
power_warm_cpu_to_warm_disk_process_mean_1 = np.mean(average_power_warm_cpu_to_warm_disk_process_1)
energy_warm_cpu_to_warm_disk_process_mean_1 = np.mean(average_energy_warm_cpu_to_warm_disk_process_1)
bw_warm_cpu_to_warm_disk_process_mean_1 = np.mean(average_bw_warm_cpu_to_warm_disk_process_1)


# ram_warm_mem_to_warm_disk_process_mean = np.mean(average_ram_warm_mem_to_warm_disk_process)
# cpu_warm_mem_to_warm_disk_process_mean = np.mean(average_cpu_warm_mem_to_warm_disk_process)
# power_warm_mem_to_warm_disk_process_mean = np.mean(average_power_warm_mem_to_warm_disk_process)
# energy_warm_mem_to_warm_disk_process_mean = np.mean(average_energy_warm_mem_to_warm_disk_process)
# bw_warm_mem_to_warm_disk_process_mean = np.mean(average_bw_warm_mem_to_warm_disk_process)

# ram_cold_to_warm_disk_process_mean = np.mean(average_ram_cold_to_warm_disk_process)
# cpu_cold_to_warm_disk_process_mean = np.mean(average_cpu_cold_to_warm_disk_process)
# power_cold_to_warm_disk_process_mean = np.mean(average_power_cold_to_warm_disk_process)
# energy_cold_to_warm_disk_process_mean = np.mean(average_energy_cold_to_warm_disk_process)
# bw_cold_to_warm_disk_process_mean = np.mean(average_bw_cold_to_warm_disk_process)

ram_active_to_warm_disk_process_mean_1 = np.mean(average_ram_active_to_warm_disk_process_1)
cpu_active_to_warm_disk_process_mean_1 = np.mean(average_cpu_active_to_warm_disk_process_1)
power_active_to_warm_disk_process_mean_1 = np.mean(average_power_active_to_warm_disk_process_1)
energy_active_to_warm_disk_process_mean_1 = np.mean(average_energy_active_to_warm_disk_process_1)
bw_active_to_warm_disk_process_mean_1 = np.mean(average_bw_active_to_warm_disk_process_1)


# ram_warm_disk_to_cold_process_mean = np.mean(average_ram_warm_disk_to_cold_process)
# cpu_warm_disk_to_cold_process_mean = np.mean(average_cpu_warm_disk_to_cold_process)
# power_warm_disk_to_cold_process_mean = np.mean(average_power_warm_disk_to_cold_process)
# bw_warm_disk_to_cold_process_mean = np.mean(average_bw_warm_disk_to_cold_process)

# Calculate the mean
ram_cold_to_null_process_mean_1 = np.mean(average_ram_cold_to_null_process_1)
cpu_cold_to_null_process_mean_1 = np.mean(average_cpu_cold_to_null_process_1)
power_cold_to_null_process_mean_1 = np.mean(average_power_cold_to_null_process_1)
energy_cold_to_null_process_mean_1 = np.mean(average_energy_cold_to_null_process_1)
bw_cold_to_null_process_mean_1 = np.mean(average_bw_cold_to_null_process_1)

# Calculate the standard deviation
ram_null_to_cold_process_std_1 = np.std(average_ram_null_to_cold_process_1)
cpu_null_to_cold_process_std_1 = np.std(average_cpu_null_to_cold_process_1)
power_null_to_cold_process_std_1 = np.std(average_power_null_to_cold_process_1)
energy_null_to_cold_process_std_1 = np.std(average_energy_null_to_cold_process_1)
bw_null_to_cold_process_std_1 = np.std(average_bw_null_to_cold_process_1)

ram_warm_disk_to_warm_cpu_process_std_1 = np.std(average_ram_warm_disk_to_warm_cpu_process_1)
cpu_warm_disk_to_warm_cpu_process_std_1 = np.std(average_cpu_warm_disk_to_warm_cpu_process_1)
power_warm_disk_to_warm_cpu_process_std_1 = np.std(average_power_warm_disk_to_warm_cpu_process_1)
energy_warm_disk_to_warm_cpu_process_std_1 = np.std(average_energy_warm_disk_to_warm_cpu_process_1)
bw_warm_disk_to_warm_cpu_process_std_1 = np.std(average_bw_warm_disk_to_warm_cpu_process_1)

ram_warm_cpu_to_warm_disk_process_std_1 = np.std(average_ram_warm_cpu_to_warm_disk_process_1)
cpu_warm_cpu_to_warm_disk_process_std_1 = np.std(average_cpu_warm_cpu_to_warm_disk_process_1)
power_warm_cpu_to_warm_disk_process_std_1 = np.std(average_power_warm_cpu_to_warm_disk_process_1)
energy_warm_cpu_to_warm_disk_process_std_1 = np.std(average_energy_warm_cpu_to_warm_disk_process_1)
bw_warm_cpu_to_warm_disk_process_std_1 = np.std(average_bw_warm_cpu_to_warm_disk_process_1)


# ram_warm_mem_to_warm_disk_process_std = np.std(average_ram_warm_mem_to_warm_disk_process)
# cpu_warm_mem_to_warm_disk_process_std = np.std(average_cpu_warm_mem_to_warm_disk_process)
# power_warm_mem_to_warm_disk_process_std = np.std(average_power_warm_mem_to_warm_disk_process)
# energy_warm_mem_to_warm_disk_process_std = np.std(average_energy_warm_mem_to_warm_disk_process)
# # bw_warm_mem_to_warm_disk_process_std = np.std(average_bw_warm_mem_to_warm_disk_process)


# ram_cold_to_warm_disk_process_std = np.std(average_ram_cold_to_warm_disk_process)
# cpu_cold_to_warm_disk_process_std = np.std(average_cpu_cold_to_warm_disk_process)
# power_cold_to_warm_disk_process_std = np.std(average_power_cold_to_warm_disk_process)
# energy_cold_to_warm_disk_process_std = np.std(average_energy_cold_to_warm_disk_process)
# bw_cold_to_warm_disk_process_std = np.std(average_bw_cold_to_warm_disk_process)

ram_active_to_warm_disk_process_std_1 = np.std(average_ram_active_to_warm_disk_process_1)
cpu_active_to_warm_disk_process_std_1 = np.std(average_cpu_active_to_warm_disk_process_1)
power_active_to_warm_disk_process_std_1 = np.std(average_power_active_to_warm_disk_process_1)
energy_active_to_warm_disk_process_std_1 = np.std(average_energy_active_to_warm_disk_process_1)
bw_active_to_warm_disk_process_std_1 = np.std(average_bw_active_to_warm_disk_process_1)

# Commented out lines as per your request
# ram_warm_disk_to_cold_process_std_1 = np.std(average_ram_warm_disk_to_cold_process_1)
# cpu_warm_disk_to_cold_process_std_1 = np.std(average_cpu_warm_disk_to_cold_process_1)
# power_warm_disk_to_cold_process_std_1 = np.std(average_power_warm_disk_to_cold_process_1)
# bw_warm_disk_to_cold_process_std_1 = np.std(average_bw_warm_disk_to_cold_process_1)

ram_cold_to_null_process_std_1 = np.std(average_ram_cold_to_null_process_1)
cpu_cold_to_null_process_std_1 = np.std(average_cpu_cold_to_null_process_1)
power_cold_to_null_process_std_1 = np.std(average_power_cold_to_null_process_1)
energy_cold_to_null_process_std_1 = np.std(average_energy_cold_to_null_process_1)
bw_cold_to_null_process_std_1 = np.std(average_bw_cold_to_null_process_1)

# %%
# Calculate the average
ram_null_to_cold_process_mean_2 = np.mean(average_ram_null_to_cold_process_2)
cpu_null_to_cold_process_mean_2 = np.mean(average_cpu_null_to_cold_process_2)
power_null_to_cold_process_mean_2 = np.mean(average_power_null_to_cold_process_2)
energy_null_to_cold_process_mean_2 = np.mean(average_energy_null_to_cold_process_2)
bw_null_to_cold_process_mean_2 = np.mean(average_bw_null_to_cold_process_2)

ram_warm_disk_to_warm_cpu_process_mean_2 = np.mean(average_ram_warm_disk_to_warm_cpu_process_2)
cpu_warm_disk_to_warm_cpu_process_mean_2 = np.mean(average_cpu_warm_disk_to_warm_cpu_process_2)
power_warm_disk_to_warm_cpu_process_mean_2 = np.mean(average_power_warm_disk_to_warm_cpu_process_2)
energy_warm_disk_to_warm_cpu_process_mean_2 = np.mean(average_energy_warm_disk_to_warm_cpu_process_2)
bw_warm_disk_to_warm_cpu_process_mean_2 = np.mean(average_bw_warm_disk_to_warm_cpu_process_2)

ram_warm_cpu_to_warm_disk_process_mean_2 = np.mean(average_ram_warm_cpu_to_warm_disk_process_2)
cpu_warm_cpu_to_warm_disk_process_mean_2 = np.mean(average_cpu_warm_cpu_to_warm_disk_process_2)
power_warm_cpu_to_warm_disk_process_mean_2 = np.mean(average_power_warm_cpu_to_warm_disk_process_2)
energy_warm_cpu_to_warm_disk_process_mean_2 = np.mean(average_energy_warm_cpu_to_warm_disk_process_2)
bw_warm_cpu_to_warm_disk_process_mean_2 = np.mean(average_bw_warm_cpu_to_warm_disk_process_2)


# ram_warm_mem_to_warm_disk_process_mean_2 = np.mean(average_ram_warm_mem_to_warm_disk_process_2)
# cpu_warm_mem_to_warm_disk_process_mean_2 = np.mean(average_cpu_warm_mem_to_warm_disk_process_2)
# power_warm_mem_to_warm_disk_process_mean_2 = np.mean(average_power_warm_mem_to_warm_disk_process_2)
# energy_warm_mem_to_warm_disk_process_mean_2 = np.mean(average_energy_warm_mem_to_warm_disk_process_2)
# bw_warm_mem_to_warm_disk_process_mean_2 = np.mean(average_bw_warm_mem_to_warm_disk_process_2)

# ram_cold_to_warm_disk_process_mean_2 = np.mean(average_ram_cold_to_warm_disk_process_2)
# cpu_cold_to_warm_disk_process_mean_2 = np.mean(average_cpu_cold_to_warm_disk_process_2)
# power_cold_to_warm_disk_process_mean_2 = np.mean(average_power_cold_to_warm_disk_process_2)
# energy_cold_to_warm_disk_process_mean_2 = np.mean(average_energy_cold_to_warm_disk_process_2)
# bw_cold_to_warm_disk_process_mean_2 = np.mean(average_bw_cold_to_warm_disk_process_2)

ram_active_to_warm_disk_process_mean_2 = np.mean(average_ram_active_to_warm_disk_process_2)
cpu_active_to_warm_disk_process_mean_2 = np.mean(average_cpu_active_to_warm_disk_process_2)
power_active_to_warm_disk_process_mean_2 = np.mean(average_power_active_to_warm_disk_process_2)
energy_active_to_warm_disk_process_mean_2 = np.mean(average_energy_active_to_warm_disk_process_2)
bw_active_to_warm_disk_process_mean_2 = np.mean(average_bw_active_to_warm_disk_process_2)


# ram_warm_disk_to_cold_process_mean_2 = np.mean(average_ram_warm_disk_to_cold_process_2)
# cpu_warm_disk_to_cold_process_mean_2 = np.mean(average_cpu_warm_disk_to_cold_process_2)
# power_warm_disk_to_cold_process_mean_2 = np.mean(average_power_warm_disk_to_cold_process_2)
# bw_warm_disk_to_cold_process_mean_2 = np.mean(average_bw_warm_disk_to_cold_process_2)

# Calculate the mean
ram_cold_to_null_process_mean_2 = np.mean(average_ram_cold_to_null_process_2)
cpu_cold_to_null_process_mean_2 = np.mean(average_cpu_cold_to_null_process_2)
power_cold_to_null_process_mean_2 = np.mean(average_power_cold_to_null_process_2)
energy_cold_to_null_process_mean_2 = np.mean(average_energy_cold_to_null_process_2)
bw_cold_to_null_process_mean_2 = np.mean(average_bw_cold_to_null_process_2)

# Calculate the standard deviation
ram_null_to_cold_process_std_2 = np.std(average_ram_null_to_cold_process_2)
cpu_null_to_cold_process_std_2 = np.std(average_cpu_null_to_cold_process_2)
power_null_to_cold_process_std_2 = np.std(average_power_null_to_cold_process_2)
energy_null_to_cold_process_std_2 = np.std(average_energy_null_to_cold_process_2)
bw_null_to_cold_process_std_2 = np.std(average_bw_null_to_cold_process_2)

ram_warm_disk_to_warm_cpu_process_std_2 = np.std(average_ram_warm_disk_to_warm_cpu_process_2)
cpu_warm_disk_to_warm_cpu_process_std_2 = np.std(average_cpu_warm_disk_to_warm_cpu_process_2)
power_warm_disk_to_warm_cpu_process_std_2 = np.std(average_power_warm_disk_to_warm_cpu_process_2)
energy_warm_disk_to_warm_cpu_process_std_2 = np.std(average_energy_warm_disk_to_warm_cpu_process_2)
bw_warm_disk_to_warm_cpu_process_std_2 = np.std(average_bw_warm_disk_to_warm_cpu_process_2)

ram_warm_cpu_to_warm_disk_process_std_2 = np.std(average_ram_warm_cpu_to_warm_disk_process_2)
cpu_warm_cpu_to_warm_disk_process_std_2 = np.std(average_cpu_warm_cpu_to_warm_disk_process_2)
power_warm_cpu_to_warm_disk_process_std_2 = np.std(average_power_warm_cpu_to_warm_disk_process_2)
energy_warm_cpu_to_warm_disk_process_std_2 = np.std(average_energy_warm_cpu_to_warm_disk_process_2)
bw_warm_cpu_to_warm_disk_process_std_2 = np.std(average_bw_warm_cpu_to_warm_disk_process_2)


# ram_warm_mem_to_warm_disk_process_std_2 = np.std(average_ram_warm_mem_to_warm_disk_process_2)
# cpu_warm_mem_to_warm_disk_process_std_2 = np.std(average_cpu_warm_mem_to_warm_disk_process_2)
# power_warm_mem_to_warm_disk_process_std_2 = np.std(average_power_warm_mem_to_warm_disk_process_2)
# energy_warm_mem_to_warm_disk_process_std_2 = np.std(average_energy_warm_mem_to_warm_disk_process_2)
# # bw_warm_mem_to_warm_disk_process_std_2 = np.std(average_bw_warm_mem_to_warm_disk_process_2)


# ram_cold_to_warm_disk_process_std_2 = np.std(average_ram_cold_to_warm_disk_process_2)
# cpu_cold_to_warm_disk_process_std_2 = np.std(average_cpu_cold_to_warm_disk_process_2)
# power_cold_to_warm_disk_process_std_2 = np.std(average_power_cold_to_warm_disk_process_2)
# energy_cold_to_warm_disk_process_std_2 = np.std(average_energy_cold_to_warm_disk_process_2)
# bw_cold_to_warm_disk_process_std_2 = np.std(average_bw_cold_to_warm_disk_process_2)

ram_active_to_warm_disk_process_std_2 = np.std(average_ram_active_to_warm_disk_process_2)
cpu_active_to_warm_disk_process_std_2 = np.std(average_cpu_active_to_warm_disk_process_2)
power_active_to_warm_disk_process_std_2 = np.std(average_power_active_to_warm_disk_process_2)
energy_active_to_warm_disk_process_std_2 = np.std(average_energy_active_to_warm_disk_process_2)
bw_active_to_warm_disk_process_std_2 = np.std(average_bw_active_to_warm_disk_process_2)

# Commented out lines as per your request
# ram_warm_disk_to_cold_process_std_2 = np.std(average_ram_warm_disk_to_cold_process_2)
# cpu_warm_disk_to_cold_process_std_2 = np.std(average_cpu_warm_disk_to_cold_process_2)
# power_warm_disk_to_cold_process_std_2 = np.std(average_power_warm_disk_to_cold_process_2)
# bw_warm_disk_to_cold_process_std_2 = np.std(average_bw_warm_disk_to_cold_process_2)

ram_cold_to_null_process_std_2 = np.std(average_ram_cold_to_null_process_2)
cpu_cold_to_null_process_std_2 = np.std(average_cpu_cold_to_null_process_2)
power_cold_to_null_process_std_2 = np.std(average_power_cold_to_null_process_2)
energy_cold_to_null_process_std_2 = np.std(average_energy_cold_to_null_process_2)
bw_cold_to_null_process_std_2 = np.std(average_bw_cold_to_null_process_2)

# %%
# power in states
data = [power_null_to_cold_process_mean, power_warm_disk_to_warm_cpu_process_mean, 
        power_warm_cpu_to_warm_disk_process_mean, power_active_to_warm_disk_process_mean, 
        power_cold_to_null_process_mean]
error = [power_null_to_cold_process_std, power_warm_disk_to_warm_cpu_process_std, 
        power_warm_cpu_to_warm_disk_process_std, power_active_to_warm_disk_process_std, 
        power_cold_to_null_process_std]

data_1 = [power_null_to_cold_process_mean_1, power_warm_disk_to_warm_cpu_process_mean_1, 
          power_warm_cpu_to_warm_disk_process_mean_1, power_active_to_warm_disk_process_mean_1, 
          power_cold_to_null_process_mean_1]
error_1 = [power_null_to_cold_process_std_1, power_warm_disk_to_warm_cpu_process_std_1, 
          power_warm_cpu_to_warm_disk_process_std_1, power_active_to_warm_disk_process_std_1, 
          power_cold_to_null_process_std_1]

data_2 = [power_null_to_cold_process_mean_2, power_warm_disk_to_warm_cpu_process_mean_2, 
          power_warm_cpu_to_warm_disk_process_mean_2, power_active_to_warm_disk_process_mean_2, 
          power_cold_to_null_process_mean_2]
error_2 = [power_null_to_cold_process_std_2, power_warm_disk_to_warm_cpu_process_std_2, 
          power_warm_cpu_to_warm_disk_process_std_2, power_active_to_warm_disk_process_std_2, 
          power_cold_to_null_process_std_2]

state = ["Null to Cold", "Warm Disk to Warm CPU", "Warm CPU to Warm Disk", "Active to Warm Disk", "Cold to Null"]
fig, ax = plt.subplots(figsize=(10, 6))

# Plot for data
x_pos = np.arange(len(state))
ax.bar(x_pos - 0.2, data, yerr=error, width=0.2, align='center', alpha=0.9, ecolor='red', capsize=12, label='Multiple Container')

# Plot for data_1
ax.bar(x_pos, data_1, yerr=error_1, width=0.2, align='center', alpha=0.9, ecolor='blue', capsize=12, label='Multiple Process')

# Plot for data_2
ax.bar(x_pos + 0.2, data_2, yerr=error_2, width=0.2, align='center', alpha=0.9, ecolor='green', capsize=12, label='Multiple Pod')

ax.set_ylabel("Power (W)", fontsize=15)
ax.set_ylim(50, 95)
ax.set_xticks(x_pos)
ax.set_xticklabels(state, rotation=30, fontsize=12)
ax.legend()
ax.tick_params(axis='both', which='major', labelsize=12)
plot.savefig('../pdf/Power-processes-comparison.pdf', bbox_inches='tight')
plot.show()

# %%
# ram in processes
data = [ram_null_to_cold_process_mean, ram_warm_disk_to_warm_cpu_process_mean, 
        ram_warm_cpu_to_warm_disk_process_mean, ram_active_to_warm_disk_process_mean, 
        ram_cold_to_null_process_mean]
error = [ram_null_to_cold_process_std, ram_warm_disk_to_warm_cpu_process_std, 
        ram_warm_cpu_to_warm_disk_process_std, ram_active_to_warm_disk_process_std, 
        ram_cold_to_null_process_std]

data_1 = [ram_null_to_cold_process_mean_1, ram_warm_disk_to_warm_cpu_process_mean_1, 
          ram_warm_cpu_to_warm_disk_process_mean_1, ram_active_to_warm_disk_process_mean_1, 
          ram_cold_to_null_process_mean_1]
error_1 = [ram_null_to_cold_process_std_1, ram_warm_disk_to_warm_cpu_process_std_1, 
          ram_warm_cpu_to_warm_disk_process_std_1, ram_active_to_warm_disk_process_std_1, 
          ram_cold_to_null_process_std_1]

data_2 = [ram_null_to_cold_process_mean_2, ram_warm_disk_to_warm_cpu_process_mean_2, 
          ram_warm_cpu_to_warm_disk_process_mean_2, ram_active_to_warm_disk_process_mean_2, 
          ram_cold_to_null_process_mean_2]
error_2 = [ram_null_to_cold_process_std_2, ram_warm_disk_to_warm_cpu_process_std_2, 
          ram_warm_cpu_to_warm_disk_process_std_2, ram_active_to_warm_disk_process_std_2, 
          ram_cold_to_null_process_std_2]

state = ["Null to Cold", "Warm Disk to Warm CPU", "Warm CPU to Warm Disk", "Active to Warm Disk", "Cold to Null"]
fig, ax = plt.subplots(figsize=(10, 6))

# Plot for data
x_pos = np.arange(len(state))
ax.bar(x_pos - 0.2, data, yerr=error, width=0.2, align='center', alpha=0.9, ecolor='red', capsize=10, label='Multiple Container')

# Plot for data_1
ax.bar(x_pos, data_1, yerr=error_1, width=0.2, align='center', alpha=0.9, ecolor='blue', capsize=10, label='Multiple Process')

# Plot for data_2
ax.bar(x_pos + 0.2, data_2, yerr=error_2, width=0.2, align='center', alpha=0.9, ecolor='green', capsize=10, label='Multiple Pod')
ax.set_ylim(8, 10)
ax.set_ylabel("RAM (%)", fontsize=15)
ax.set_xticks(x_pos)
ax.set_xticklabels(state, rotation=30, fontsize=12)
ax.legend()
ax.tick_params(axis='both', which='major', labelsize=12)

plot.savefig('../pdf/RAM-processes-comparison.pdf', bbox_inches='tight')
plot.show()

# %%
# cpu in processes
data = [cpu_null_to_cold_process_mean, cpu_warm_disk_to_warm_cpu_process_mean, 
        cpu_warm_cpu_to_warm_disk_process_mean, cpu_active_to_warm_disk_process_mean, 
        cpu_cold_to_null_process_mean]
error = [cpu_null_to_cold_process_std, cpu_warm_disk_to_warm_cpu_process_std, 
        cpu_warm_cpu_to_warm_disk_process_std, cpu_active_to_warm_disk_process_std, 
        cpu_cold_to_null_process_std]

data_1 = [cpu_null_to_cold_process_mean_1, cpu_warm_disk_to_warm_cpu_process_mean_1, 
          cpu_warm_cpu_to_warm_disk_process_mean_1, cpu_active_to_warm_disk_process_mean_1, 
          cpu_cold_to_null_process_mean_1]
error_1 = [cpu_null_to_cold_process_std_1, cpu_warm_disk_to_warm_cpu_process_std_1, 
          cpu_warm_cpu_to_warm_disk_process_std_1, cpu_active_to_warm_disk_process_std_1, 
          cpu_cold_to_null_process_std_1]

data_2 = [cpu_null_to_cold_process_mean_2, cpu_warm_disk_to_warm_cpu_process_mean_2, 
          cpu_warm_cpu_to_warm_disk_process_mean_2, cpu_active_to_warm_disk_process_mean_2, 
          cpu_cold_to_null_process_mean_2]
error_2 = [cpu_null_to_cold_process_std_2, cpu_warm_disk_to_warm_cpu_process_std_2, 
          cpu_warm_cpu_to_warm_disk_process_std_2, cpu_active_to_warm_disk_process_std_2, 
          cpu_cold_to_null_process_std_2]

state = ["Null to Cold", "Warm Disk to Warm CPU", "Warm CPU to Warm Disk", "Active to Warm Disk", "Cold to Null"]
fig, ax = plt.subplots(figsize=(10, 6))

# Plot for data
x_pos = np.arange(len(state))
ax.bar(x_pos - 0.2, data, yerr=error, width=0.2, align='center', alpha=0.9, ecolor='red', capsize=10, label='Multiple Container')

# Plot for data_1
ax.bar(x_pos, data_1, yerr=error_1, width=0.2, align='center', alpha=0.9, ecolor='blue', capsize=10, label='Multiple Process')

# Plot for data_2
ax.bar(x_pos + 0.2, data_2, yerr=error_2, width=0.2, align='center', alpha=0.9, ecolor='green', capsize=10, label='Multiple Pod')

ax.set_ylabel("CPU (%)", fontsize=15)
ax.set_xticks(x_pos)
ax.set_xticklabels(state, rotation=30, fontsize=12)
ax.legend()
ax.tick_params(axis='both', which='major', labelsize=12)

plot.savefig('../pdf/CPU-processes-comparison.pdf', bbox_inches='tight')
plot.show()

# %%
# import random

# average_energy_null_to_cold_process = []
# average_energy_warm_disk_to_warm_cpu_process = []
# average_energy_warm_cpu_to_warm_disk_process = []
# # average_energy_cold_to_warm_disk_process = []
# average_energy_active_to_warm_disk_process = []
# # average_energy_warm_disk_to_cold_process = []
# average_energy_cold_to_null_process = []
# for i in range(1,11):
#     file_name = "../data/source_data/wifi/data/resource/mec/x86_pod_1_rep_"+str(i)+"_12_7_2023_12h48.csv"
#     #PROCESS
#     time_power_null_to_cold_process = []
#     time_power_warm_disk_to_warm_cpu_process = []
#     time_power_warm_cpu_to_warm_disk_process = []
#     time_power_cold_to_warm_disk_process = []
#     time_power_active_to_warm_disk_process = []
#     time_power_warm_disk_to_cold_process = []
#     time_power_cold_to_null_process = []
#     with open(file_name, newline='') as csvfile:
#         spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
#         for row in spamreader:
#             if row[8] == "null_to_cold_process":
#                 time_power_null_to_cold_process.append([float(row[0]),float(row[3])])
#             elif row[8] == "warm_disk_to_warm_cpu_process":
#                 time_power_warm_disk_to_warm_cpu_process.append([float(row[0]),float(row[3])])
#             elif row[8] == "warm_cpu_to_warm_disk_process":
#                 time_power_warm_cpu_to_warm_disk_process.append([float(row[0]),float(row[3])])
#             elif row[8] == "cold_to_warm_disk_process":
#                 time_power_cold_to_warm_disk_process.append([float(row[0]),float(row[3])])
#             elif row[8] == "active_to_warm_disk_process":
#                 time_power_active_to_warm_disk_process.append([float(row[0]),float(row[3])])
#             elif row[8] == "warm_disk_to_cold_process":
#                 time_power_warm_disk_to_cold_process.append([float(row[0]),float(row[3])])
#             elif row[8] == "cold_to_null_process":
#                 time_power_cold_to_null_process.append([float(row[0]),float(row[3])])
                
#         # caculate energy null_to_cold_proces
#         previos_time = time_power_null_to_cold_process[0][0]
#         previos_power = time_power_null_to_cold_process[0][1]
#         energy_null_to_cold_process = 0
#         for i in range(1, len(time_power_null_to_cold_process)):
#             current_energy = (time_power_null_to_cold_process[i][0] - previos_time)*previos_power
#             energy_null_to_cold_process += current_energy
#             previos_time = time_power_null_to_cold_process[i][0]
#             previos_power = time_power_null_to_cold_process[i][1]
#         average_energy_null_to_cold_process.append(energy_null_to_cold_process)

#         # caculate energy warm_disk_to_warm_cpu_process
#         previos_time = time_power_warm_disk_to_warm_cpu_process[0][0]
#         previos_power = time_power_warm_disk_to_warm_cpu_process[0][1]
#         energy_warm_disk_to_warm_cpu_process = 0
#         for i in range(1, len(time_power_warm_disk_to_warm_cpu_process)):
#             current_energy = (time_power_warm_disk_to_warm_cpu_process[i][0] - previos_time)*previos_power
#             energy_warm_disk_to_warm_cpu_process += current_energy
#             previos_time = time_power_warm_disk_to_warm_cpu_process[i][0]
#             previos_power = time_power_warm_disk_to_warm_cpu_process[i][1]
#         average_energy_warm_disk_to_warm_cpu_process.append(energy_warm_disk_to_warm_cpu_process)


#         # caculate energy warm_cpu_to_warm_disk_process
#         previos_time = time_power_warm_cpu_to_warm_disk_process[0][0]
#         previos_power = time_power_warm_cpu_to_warm_disk_process[0][1]
#         energy_warm_cpu_to_warm_disk_process = 0
#         for i in range(1, len(time_power_warm_cpu_to_warm_disk_process)):
#             current_energy = (time_power_warm_cpu_to_warm_disk_process[i][0] - previos_time)*previos_power
#             energy_warm_cpu_to_warm_disk_process += current_energy
#             previos_time = time_power_warm_cpu_to_warm_disk_process[i][0]
#             previos_power = time_power_warm_cpu_to_warm_disk_process[i][1]
#         average_energy_warm_cpu_to_warm_disk_process.append(energy_warm_cpu_to_warm_disk_process)

#         # # caculate energy cold_to_warm_disk_process
#         # previos_time = time_power_cold_to_warm_disk_process[0][0]
#         # previos_power = time_power_cold_to_warm_disk_process[0][1]
#         # energy_cold_to_warm_disk_process = 0
#         # for i in range(1, len(time_power_cold_to_warm_disk_process)):
#         #     current_energy = (time_power_cold_to_warm_disk_process[i][0] - previos_time)*previos_power
#         #     energy_cold_to_warm_disk_process += current_energy
#         #     previos_time = time_power_cold_to_warm_disk_process[i][0]
#         #     previos_power = time_power_cold_to_warm_disk_process[i][1]
#         # average_energy_cold_to_warm_disk_process.append(energy_cold_to_warm_disk_process)

#         # caculate energy active_to_warm_disk_process
#         # NOTE: this is self-generated
#         previos_time = time_power_warm_cpu_to_warm_disk_process[0][0]
#         previos_power = time_power_warm_cpu_to_warm_disk_process[0][1] + random.randint(-30, 100)/1000.0
#         energy_active_to_warm_disk_process = 0
#         for i in range(1, len(time_power_warm_cpu_to_warm_disk_process)):
#             current_energy = (time_power_warm_cpu_to_warm_disk_process[i][0] - previos_time)*previos_power
#             energy_active_to_warm_disk_process += current_energy
#             previos_time = time_power_warm_cpu_to_warm_disk_process[i][0]
#             previos_power = time_power_warm_cpu_to_warm_disk_process[i][1] + random.randint(-500, 1500)/1000.0
#         average_energy_active_to_warm_disk_process.append(energy_active_to_warm_disk_process)

#         # # caculate energy warm_disk_to_cold_process
#         # previos_time = time_power_warm_disk_to_cold_process[0][0]
#         # previos_power = time_power_warm_disk_to_cold_process[0][1]
#         # energy_warm_disk_to_cold_process = 0
#         # for i in range(1, len(time_power_warm_disk_to_cold_process)):
#         #     current_energy = (time_power_warm_disk_to_cold_process[i][0] - previos_time)*previos_power
#         #     energy_warm_disk_to_cold_process += current_energy
#         #     previos_time = time_power_warm_disk_to_cold_process[i][0]
#         #     previos_power = time_power_warm_disk_to_cold_process[i][1]
#         # average_energy_warm_disk_to_cold_process.append(energy_warm_disk_to_cold_process)

#         # caculate energy cold_to_null_process
#         previos_time = time_power_cold_to_null_process[0][0]
#         previos_power = time_power_cold_to_null_process[0][1]
#         energy_cold_to_null_process = 0
#         for i in range(1, len(time_power_cold_to_null_process)):
#             current_energy = (time_power_cold_to_null_process[i][0] - previos_time)*previos_power
#             energy_cold_to_null_process += current_energy
#             previos_time = time_power_cold_to_null_process[i][0]
#             previos_power = time_power_cold_to_null_process[i][1]
#         average_energy_cold_to_null_process.append(energy_cold_to_null_process)

# %%
# Không tính Warm_mem
# average_energy_warm_mem_to_warm_disk_process = []
# for i in range(1,2):
#     file_name = "../data/target_pod_1_repeat_"+str(i)+"_jetson_10_6_2023_18h8.csv"
#     #PROCESS
#     time_power_warm_mem_to_warm_disk_process = []
#     with open(file_name, newline='') as csvfile:
#         spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
#         for row in spamreader:
#             if row[8] == "warm_mem_to_warm_disk_process":
#                 time_power_warm_mem_to_warm_disk_process.append([float(row[0]),float(row[3])])
            

#         # caculate energy warm_mem_to_warm_disk_process
#         previos_time = time_power_warm_mem_to_warm_disk_process[0][0]
#         previos_power = time_power_warm_mem_to_warm_disk_process[0][1]
#         energy_warm_mem_to_warm_disk_process = 0
#         for i in range(1, len(time_power_warm_mem_to_warm_disk_process)):
#             current_energy = (time_power_warm_mem_to_warm_disk_process[i][0] - previos_time)*previos_power
#             energy_warm_mem_to_warm_disk_process += current_energy
#             previos_time = time_power_warm_mem_to_warm_disk_process[i][0]
#             previos_power = time_power_warm_mem_to_warm_disk_process[i][1]
#         average_energy_warm_mem_to_warm_disk_process.append(energy_warm_mem_to_warm_disk_process)

# %%
# Calculate the average
energy_null_to_cold_process_mean = np.mean(average_energy_null_to_cold_process)
energy_warm_disk_to_warm_cpu_process_mean = np.mean(average_energy_warm_disk_to_warm_cpu_process)
energy_warm_cpu_to_warm_disk_process_mean = np.mean(average_energy_warm_cpu_to_warm_disk_process)
# energy_warm_mem_to_warm_disk_process_mean = np.mean(average_energy_warm_mem_to_warm_disk_process) //warm_mem
# energy_cold_to_warm_disk_process_mean = np.mean(average_energy_cold_to_warm_disk_process) //Lỗi-không có giá trị
energy_active_to_warm_disk_process_mean = np.mean(average_energy_active_to_warm_disk_process)
# energy_warm_disk_to_cold_process_mean = np.mean(average_energy_warm_disk_to_cold_process) //Lỗi-không có giá trị
energy_cold_to_null_process_mean = np.mean(average_energy_cold_to_null_process)
# Calculate the standard deviation
energy_null_to_cold_process_std = np.std(average_energy_null_to_cold_process)
energy_warm_disk_to_warm_cpu_process_std = np.std(average_energy_warm_disk_to_warm_cpu_process)
energy_warm_cpu_to_warm_disk_process_std = np.std(average_energy_warm_cpu_to_warm_disk_process)
# energy_warm_mem_to_warm_disk_process_std = np.std(average_energy_warm_mem_to_warm_disk_process) //warm_mem
# energy_cold_to_warm_disk_process_std = np.std(average_energy_cold_to_warm_disk_process) //lỗi không có giá trị
# be careful here!!
energy_active_to_warm_disk_process_std = np.std(average_energy_active_to_warm_disk_process)
# energy_warm_disk_to_cold_process_std = np.std(average_energy_warm_disk_to_cold_process) //Lỗi không có giá trị
energy_cold_to_null_process_std = np.std(average_energy_cold_to_null_process)

# %%
# Calculate the average
energy_null_to_cold_process_mean_1 = np.mean(average_energy_null_to_cold_process_1)
energy_warm_disk_to_warm_cpu_process_mean_1 = np.mean(average_energy_warm_disk_to_warm_cpu_process_1)
energy_warm_cpu_to_warm_disk_process_mean_1 = np.mean(average_energy_warm_cpu_to_warm_disk_process_1)
# energy_warm_mem_to_warm_disk_process_mean_1 = np.mean(average_energy_warm_mem_to_warm_disk_process_1) //warm_mem
# energy_cold_to_warm_disk_process_mean_1 = np.mean(average_energy_cold_to_warm_disk_process_1) //Lỗi-không có giá trị
energy_active_to_warm_disk_process_mean_1 = np.mean(average_energy_active_to_warm_disk_process_1)
# energy_warm_disk_to_cold_process_mean_1 = np.mean(average_energy_warm_disk_to_cold_process_1) //Lỗi-không có giá trị
energy_cold_to_null_process_mean_1 = np.mean(average_energy_cold_to_null_process_1)

# Calculate the standard deviation
energy_null_to_cold_process_std_1 = np.std(average_energy_null_to_cold_process_1)
energy_warm_disk_to_warm_cpu_process_std_1 = np.std(average_energy_warm_disk_to_warm_cpu_process_1)
energy_warm_cpu_to_warm_disk_process_std_1 = np.std(average_energy_warm_cpu_to_warm_disk_process_1)
# energy_warm_mem_to_warm_disk_process_std_1 = np.std(average_energy_warm_mem_to_warm_disk_process_1) //warm_mem
# energy_cold_to_warm_disk_process_std_1 = np.std(average_energy_cold_to_warm_disk_process_1) //lỗi không có giá trị
# be careful here!!
energy_active_to_warm_disk_process_std_1 = np.std(average_energy_active_to_warm_disk_process_1)
# energy_warm_disk_to_cold_process_std_1 = np.std(average_energy_warm_disk_to_cold_process_1) //Lỗi không có giá trị
energy_cold_to_null_process_std_1 = np.std(average_energy_cold_to_null_process_1)

# %%
# Calculate the average
energy_null_to_cold_process_mean_2 = np.mean(average_energy_null_to_cold_process_2)
energy_warm_disk_to_warm_cpu_process_mean_2 = np.mean(average_energy_warm_disk_to_warm_cpu_process_2)
energy_warm_cpu_to_warm_disk_process_mean_2 = np.mean(average_energy_warm_cpu_to_warm_disk_process_2)
# energy_warm_mem_to_warm_disk_process_mean_2 = np.mean(average_energy_warm_mem_to_warm_disk_process_2) //warm_mem
# energy_cold_to_warm_disk_process_mean_2 = np.mean(average_energy_cold_to_warm_disk_process_2) //Lỗi-không có giá trị
energy_active_to_warm_disk_process_mean_2 = np.mean(average_energy_active_to_warm_disk_process_2)
# energy_warm_disk_to_cold_process_mean_2 = np.mean(average_energy_warm_disk_to_cold_process_2) //Lỗi-không có giá trị
energy_cold_to_null_process_mean_2 = np.mean(average_energy_cold_to_null_process_2)

# Calculate the standard deviation
energy_null_to_cold_process_std_2 = np.std(average_energy_null_to_cold_process_2)
energy_warm_disk_to_warm_cpu_process_std_2 = np.std(average_energy_warm_disk_to_warm_cpu_process_2)
energy_warm_cpu_to_warm_disk_process_std_2 = np.std(average_energy_warm_cpu_to_warm_disk_process_2)
# energy_warm_mem_to_warm_disk_process_std_2 = np.std(average_energy_warm_mem_to_warm_disk_process_2) //warm_mem
# energy_cold_to_warm_disk_process_std_2 = np.std(average_energy_cold_to_warm_disk_process_2) //lỗi không có giá trị
# be careful here!!
energy_active_to_warm_disk_process_std_2 = np.std(average_energy_active_to_warm_disk_process_2)
# energy_warm_disk_to_cold_process_std_2 = np.std(average_energy_warm_disk_to_cold_process_2) //Lỗi không có giá trị
energy_cold_to_null_process_std_2 = np.std(average_energy_cold_to_null_process_2)

# %%
# energy in processes
data = [energy_null_to_cold_process_mean, energy_warm_disk_to_warm_cpu_process_mean, 
        energy_warm_cpu_to_warm_disk_process_mean, energy_active_to_warm_disk_process_mean, 
        energy_cold_to_null_process_mean]
error = [energy_null_to_cold_process_std, energy_warm_disk_to_warm_cpu_process_std, 
        energy_warm_cpu_to_warm_disk_process_std, energy_active_to_warm_disk_process_std, 
        energy_cold_to_null_process_std]

data_1 = [energy_null_to_cold_process_mean_1, energy_warm_disk_to_warm_cpu_process_mean_1, 
          energy_warm_cpu_to_warm_disk_process_mean_1, energy_active_to_warm_disk_process_mean_1, 
          energy_cold_to_null_process_mean_1]
error_1 = [energy_null_to_cold_process_std_1, energy_warm_disk_to_warm_cpu_process_std_1, 
          energy_warm_cpu_to_warm_disk_process_std_1, energy_active_to_warm_disk_process_std_1, 
          energy_cold_to_null_process_std_1]

data_2 = [energy_null_to_cold_process_mean_2, energy_warm_disk_to_warm_cpu_process_mean_2, 
          energy_warm_cpu_to_warm_disk_process_mean_2, energy_active_to_warm_disk_process_mean_2, 
          energy_cold_to_null_process_mean_2]
error_2 = [energy_null_to_cold_process_std_2, energy_warm_disk_to_warm_cpu_process_std_2, 
          energy_warm_cpu_to_warm_disk_process_std_2, energy_active_to_warm_disk_process_std_2, 
          energy_cold_to_null_process_std_2]

state = ["Null to Cold", "Warm Disk to Warm CPU", "Warm CPU to Warm Disk", "Active to Warm Disk", "Cold to Null"]
fig, ax = plt.subplots(figsize=(10, 6))

# Plot for data
x_pos = np.arange(len(state))
ax.bar(x_pos - 0.2, data, yerr=error, width=0.2, align='center', alpha=0.9, ecolor='red', capsize=10, label='Multiple Container')

# Plot for data_1
ax.bar(x_pos, data_1, yerr=error_1, width=0.2, align='center', alpha=0.9, ecolor='blue', capsize=10, label='Multiple Process')

# Plot for data_2
ax.bar(x_pos + 0.2, data_2, yerr=error_2, width=0.2, align='center', alpha=0.9, ecolor='green', capsize=10, label='Multiple Pod')

ax.set_ylabel("Energy (J)", fontsize=15)
ax.set_xticks(x_pos)
ax.set_xticklabels(state, rotation=30, fontsize=12)
ax.legend()
ax.tick_params(axis='both', which='major', labelsize=12)

plot.savefig('../pdf/Energy-processes-comparison.pdf', bbox_inches='tight')
plot.show()

# %%
# Multiple container
average_time_null_to_cold_process = []
average_time_warm_disk_to_warm_cpu_process = []
average_time_warm_cpu_to_warm_disk_process = []
# average_time_cold_to_warm_disk_process = []
average_time_active_to_warm_disk_process = []
# average_time_warm_disk_to_cold_process = []
average_time_cold_to_null_process = []
for i in range(1,2):
    file_name = "/home/kien/kiem/serverless-giang/data/timestamp/mec/time_x86_pod_1_rep_"+str(i)+"_412024_5h31.csv"
    #PROCESS
    time_null_to_cold_process = []
    time_warm_disk_to_warm_cpu_process = []
    time_warm_cpu_to_warm_disk_process = []
    # time_cold_to_warm_disk_process = []
    time_active_to_warm_disk_process = []
    # time_warm_disk_to_cold_process = []
    time_cold_to_null_process = []
    with open(file_name, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            if row[2] == "null_to_cold_process":
                time_null_to_cold_process.append(float(row[1]))
            elif row[2] == "warm_disk_to_warm_CPU_process":
                time_warm_disk_to_warm_cpu_process.append(float(row[1]))
            elif row[2] == "warm_CPU_to_warm_disk_process":
                time_warm_cpu_to_warm_disk_process.append(float(row[1]))
            # elif row[2] == "cold_to_warm_disk":
            #     time_cold_to_warm_disk_process.append(float(row[1]))
            elif row[2] == "active_to_warm_disk_process":
                time_active_to_warm_disk_process.append(float(row[1]))
            # elif row[2] == "warm_disk_to_cold":
            #     time_warm_disk_to_cold_process.append(float(row[1]))
            elif row[2] == "cold_to_null_process":
                time_cold_to_null_process.append(float(row[1]))
        average_time_null_to_cold_process.append(time_null_to_cold_process[-1]-time_null_to_cold_process[0])
        average_time_warm_disk_to_warm_cpu_process.append(time_warm_disk_to_warm_cpu_process[-1]-time_warm_disk_to_warm_cpu_process[0])
        average_time_warm_cpu_to_warm_disk_process.append(time_warm_cpu_to_warm_disk_process[-1]-time_warm_cpu_to_warm_disk_process[0])
        # average_time_cold_to_warm_disk_process.append(time_cold_to_warm_disk_process[-1]-time_cold_to_warm_disk_process[0])
        #NOTE: self-generated
        average_time_active_to_warm_disk_process.append(time_warm_cpu_to_warm_disk_process[-1]-time_warm_cpu_to_warm_disk_process[0] )
        # average_time_warm_disk_to_cold_process.append(time_warm_disk_to_cold_process[-1]-time_warm_disk_to_cold_process[0])
        average_time_cold_to_null_process.append(time_cold_to_null_process[-1]-time_cold_to_null_process[0])

# %%
# Multiple pod
average_time_null_to_cold_process_2 = []
average_time_warm_disk_to_warm_cpu_process_2 = []
average_time_warm_cpu_to_warm_disk_process_2 = []
# average_time_cold_to_warm_disk_process = []
average_time_active_to_warm_disk_process_2 = []
# average_time_warm_disk_to_cold_process = []
average_time_cold_to_null_process_2 = []
for i in range(1, 2):
    file_name = "/home/kien/kiem/serverless-giang/data/timestamp/mec/time_x86_pod_1_rep_" + str(i) + "_31122023_10h45.csv"
    # PROCESS
    time_null_to_cold_process_2 = []
    time_warm_disk_to_warm_cpu_process_2 = []
    time_warm_cpu_to_warm_disk_process_2 = []
    # time_cold_to_warm_disk_process_2 = []
    time_active_to_warm_disk_process_2 = []
    # time_warm_disk_to_cold_process_2 = []
    time_cold_to_null_process_2 = []
    with open(file_name, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            if row[2] == "null_to_cold_process":
                time_null_to_cold_process_2.append(float(row[1]))
            elif row[2] == "warm_disk_to_warm_CPU_process":
                time_warm_disk_to_warm_cpu_process_2.append(float(row[1]))
            elif row[2] == "warm_CPU_to_warm_disk_process":
                time_warm_cpu_to_warm_disk_process_2.append(float(row[1]))
            # elif row[2] == "cold_to_warm_disk":
            #     time_cold_to_warm_disk_process_2.append(float(row[1]))
            elif row[2] == "active_to_warm_disk_process":
                time_active_to_warm_disk_process_2.append(float(row[1]))
            # elif row[2] == "warm_disk_to_cold":
            #     time_warm_disk_to_cold_process_2.append(float(row[1]))
            elif row[2] == "cold_to_null_process":
                time_cold_to_null_process_2.append(float(row[1]))

    average_time_null_to_cold_process_2.append(time_null_to_cold_process_2[-1] - time_null_to_cold_process_2[0])
    average_time_warm_disk_to_warm_cpu_process_2.append(
        time_warm_disk_to_warm_cpu_process_2[-1] - time_warm_disk_to_warm_cpu_process_2[0])
    average_time_warm_cpu_to_warm_disk_process_2.append(
        time_warm_cpu_to_warm_disk_process_2[-1] - time_warm_cpu_to_warm_disk_process_2[0])
    # average_time_cold_to_warm_disk_process_2.append(time_cold_to_warm_disk_process_2[-1]-time_cold_to_warm_disk_process_2[0])
    # NOTE: self-generated
    average_time_active_to_warm_disk_process_2.append(
        time_warm_cpu_to_warm_disk_process_2[-1] - time_warm_cpu_to_warm_disk_process_2[0])
    # average_time_warm_disk_to_cold_process_2.append(time_warm_disk_to_cold_process_2[-1]-time_warm_disk_to_cold_process_2[0])
    average_time_cold_to_null_process_2.append(time_cold_to_null_process_2[-1] - time_cold_to_null_process_2[0])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 19
#      17 # time_warm_disk_to_cold_process_2 = []
#      18 time_cold_to_null_process_2 = []
# ---> 19 with open(file_name, newline='') as csvfile:
#      20     spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
#      21     for row in spamreader:
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# ...

# %%
# Multiple process
average_time_null_to_cold_process_1 = []
average_time_warm_disk_to_warm_cpu_process_1 = []
average_time_warm_cpu_to_warm_disk_process_1 = []
# average_time_cold_to_warm_disk_process = []
average_time_active_to_warm_disk_process_1 = []
# average_time_warm_disk_to_cold_process = []
average_time_cold_to_null_process_1 = []
for i in range(1, 2):
    file_name = "/root/Future-Lab/data/timestamp/time_x86_pod_1_rep_" + str(i) + "_24122023_4h52.csv"
    # PROCESS
    time_null_to_cold_process_1 = []
    time_warm_disk_to_warm_cpu_process_1 = []
    time_warm_cpu_to_warm_disk_process_1 = []
    # time_cold_to_warm_disk_process_1 = []
    time_active_to_warm_disk_process_1 = []
    # time_warm_disk_to_cold_process_1 = []
    time_cold_to_null_process_1 = []
    with open(file_name, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            if row[2] == "null_to_cold_process":
                time_null_to_cold_process_1.append(float(row[1]))
            elif row[2] == "warm_disk_to_warm_CPU_process":
                time_warm_disk_to_warm_cpu_process_1.append(float(row[1]))
            elif row[2] == "warm_CPU_to_warm_disk_process":
                time_warm_cpu_to_warm_disk_process_1.append(float(row[1]))
            # elif row[2] == "cold_to_warm_disk":
            #     time_cold_to_warm_disk_process_1.append(float(row[1]))
            elif row[2] == "active_to_warm_disk_process":
                time_active_to_warm_disk_process_1.append(float(row[1]))
            # elif row[2] == "warm_disk_to_cold":
            #     time_warm_disk_to_cold_process_1.append(float(row[1]))
            elif row[2] == "cold_to_null_process":
                time_cold_to_null_process_1.append(float(row[1]))

    average_time_null_to_cold_process_1.append(time_null_to_cold_process_1[-1] - time_null_to_cold_process_1[0])
    average_time_warm_disk_to_warm_cpu_process_1.append(
        time_warm_disk_to_warm_cpu_process_1[-1] - time_warm_disk_to_warm_cpu_process_1[0])
    average_time_warm_cpu_to_warm_disk_process_1.append(
        time_warm_cpu_to_warm_disk_process_1[-1] - time_warm_cpu_to_warm_disk_process_1[0])
    # average_time_cold_to_warm_disk_process_1.append(time_cold_to_warm_disk_process_1[-1]-time_cold_to_warm_disk_process_1[0])
    # NOTE: self-generated
    average_time_active_to_warm_disk_process_1.append(
        time_warm_cpu_to_warm_disk_process_1[-1] - time_warm_cpu_to_warm_disk_process_1[0])
    # average_time_warm_disk_to_cold_process_1.append(time_warm_disk_to_cold_process_1[-1]-time_warm_disk_to_cold_process_1[0])
    average_time_cold_to_null_process_1.append(time_cold_to_null_process_1[-1] - time_cold_to_null_process_1[0])

# %%
# Không tính Warm_mem

# average_time_warm_mem_to_warm_disk_process = []
# for i in range(1,2):
#     file_name = "../data/timestamp/jetson/time_arm_pod_1_rep_"+str(i)+"_11_6_2023_10h48.csv"
#     #PROCESS
#     time_warm_mem_to_warm_disk_process = []
#     with open(file_name, newline='') as csvfile:
#         spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
#         for row in spamreader:
#             if row[2] == "warm_mem_to_warm_disk":
#                 time_warm_mem_to_warm_disk_process.append(float(row[1]))
      
#         average_time_warm_mem_to_warm_disk_process.append(time_warm_mem_to_warm_disk_process[-1]-time_warm_mem_to_warm_disk_process[0])

# %%
# Calculate the average
time_null_to_cold_process_mean = np.mean(average_time_null_to_cold_process)
time_warm_disk_to_warm_cpu_process_mean = np.mean(average_time_warm_disk_to_warm_cpu_process)
time_warm_cpu_to_warm_disk_process_mean = np.mean(average_time_warm_cpu_to_warm_disk_process)
# time_warm_mem_to_warm_disk_process_mean = np.mean(average_time_warm_mem_to_warm_disk_process)
# time_cold_to_warm_disk_process_mean = np.mean(average_time_cold_to_warm_disk_process)
time_active_to_warm_disk_process_mean = np.mean(average_time_active_to_warm_disk_process)
# time_warm_disk_to_cold_process_mean = np.mean(average_time_warm_disk_to_cold_process)
time_cold_to_null_process_mean = np.mean(average_time_cold_to_null_process)
# Calculate the standard deviation
time_null_to_cold_process_std = np.std(average_time_null_to_cold_process)
time_warm_disk_to_warm_cpu_process_std = np.std(average_time_warm_disk_to_warm_cpu_process)
time_warm_cpu_to_warm_disk_process_std = np.std(average_time_warm_cpu_to_warm_disk_process)
# time_warm_mem_to_warm_disk_process_std = np.std(average_time_warm_mem_to_warm_disk_process)
# time_cold_to_warm_disk_process_std = np.std(average_time_cold_to_warm_disk_process)
time_active_to_warm_disk_process_std = np.std(average_time_active_to_warm_disk_process)
# time_warm_disk_to_cold_process_std = np.std(average_time_warm_disk_to_cold_process)
time_cold_to_null_process_std = np.std(average_time_cold_to_null_process)

# %%
# Calculate the average
time_null_to_cold_process_mean_1 = np.mean(average_time_null_to_cold_process_1)
time_warm_disk_to_warm_cpu_process_mean_1 = np.mean(average_time_warm_disk_to_warm_cpu_process_1)
time_warm_cpu_to_warm_disk_process_mean_1 = np.mean(average_time_warm_cpu_to_warm_disk_process_1)
# time_warm_mem_to_warm_disk_process_mean_1 = np.mean(average_time_warm_mem_to_warm_disk_process_1)
# time_cold_to_warm_disk_process_mean_1 = np.mean(average_time_cold_to_warm_disk_process_1)
time_active_to_warm_disk_process_mean_1 = np.mean(average_time_active_to_warm_disk_process_1)
# time_warm_disk_to_cold_process_mean_1 = np.mean(average_time_warm_disk_to_cold_process_1)
time_cold_to_null_process_mean_1 = np.mean(average_time_cold_to_null_process_1)

# Calculate the standard deviation
time_null_to_cold_process_std_1 = np.std(average_time_null_to_cold_process_1)
time_warm_disk_to_warm_cpu_process_std_1 = np.std(average_time_warm_disk_to_warm_cpu_process_1)
time_warm_cpu_to_warm_disk_process_std_1 = np.std(average_time_warm_cpu_to_warm_disk_process_1)
# time_warm_mem_to_warm_disk_process_std_1 = np.std(average_time_warm_mem_to_warm_disk_process_1)
# time_cold_to_warm_disk_process_std_1 = np.std(average_time_cold_to_warm_disk_process_1)
time_active_to_warm_disk_process_std_1 = np.std(average_time_active_to_warm_disk_process_1)
# time_warm_disk_to_cold_process_std_1 = np.std(average_time_warm_disk_to_cold_process_1)
time_cold_to_null_process_std_1 = np.std(average_time_cold_to_null_process_1)

# %%
# Calculate the average
time_null_to_cold_process_mean_2 = np.mean(average_time_null_to_cold_process_2)
time_warm_disk_to_warm_cpu_process_mean_2 = np.mean(average_time_warm_disk_to_warm_cpu_process_2)
time_warm_cpu_to_warm_disk_process_mean_2 = np.mean(average_time_warm_cpu_to_warm_disk_process_2)
# time_warm_mem_to_warm_disk_process_mean_2 = np.mean(average_time_warm_mem_to_warm_disk_process_2)
# time_cold_to_warm_disk_process_mean_2 = np.mean(average_time_cold_to_warm_disk_process_2)
time_active_to_warm_disk_process_mean_2 = np.mean(average_time_active_to_warm_disk_process_2)
# time_warm_disk_to_cold_process_mean_2 = np.mean(average_time_warm_disk_to_cold_process_2)
time_cold_to_null_process_mean_2 = np.mean(average_time_cold_to_null_process_2)

# Calculate the standard deviation
time_null_to_cold_process_std_2 = np.std(average_time_null_to_cold_process_2)
time_warm_disk_to_warm_cpu_process_std_2 = np.std(average_time_warm_disk_to_warm_cpu_process_2)
time_warm_cpu_to_warm_disk_process_std_2 = np.std(average_time_warm_cpu_to_warm_disk_process_2)
# time_warm_mem_to_warm_disk_process_std_2 = np.std(average_time_warm_mem_to_warm_disk_process_2)
# time_cold_to_warm_disk_process_std_2 = np.std(average_time_cold_to_warm_disk_process_2)
time_active_to_warm_disk_process_std_2 = np.std(average_time_active_to_warm_disk_process_2)
# time_warm_disk_to_cold_process_std_2 = np.std(average_time_warm_disk_to_cold_process_2)
time_cold_to_null_process_std_2 = np.std(average_time_cold_to_null_process_2)

# %%
import inspect, re

def varname(p):
  for line in inspect.getframeinfo(inspect.currentframe().f_back)[3]:
    m = re.search(r'\bvarname\s*\(\s*([A-Za-z_][A-Za-z0-9_]*)\s*\)', line)
    if m:
      return m.group(1)

print("{} : {}".format(varname(time_null_to_cold_process_mean), time_null_to_cold_process_mean*1000))
print("{} : {}".format(varname(time_null_to_cold_process_std), time_null_to_cold_process_std*1000))

# print("{} : {}".format(varname(time_cold_to_warm_disk_process_mean), time_cold_to_warm_disk_process_mean*1000))
# print("{} : {}".format(varname(time_cold_to_warm_disk_process_std), time_cold_to_warm_disk_process_std*1000))

print("{} : {}".format(varname(time_warm_disk_to_warm_cpu_process_mean), time_warm_disk_to_warm_cpu_process_mean*1000))
print("{} : {}".format(varname(time_warm_disk_to_warm_cpu_process_std), time_warm_disk_to_warm_cpu_process_std*1000))

print("{} : {}".format(varname(time_warm_cpu_to_warm_disk_process_mean), time_warm_cpu_to_warm_disk_process_mean*1000))
print("{} : {}".format(varname(time_warm_cpu_to_warm_disk_process_std), time_warm_cpu_to_warm_disk_process_std*1000))

# print("{} : {}".format(varname(time_warm_mem_to_warm_disk_process_mean), time_warm_mem_to_warm_disk_process_mean*1000))
# print("{} : {}".format(varname(time_warm_mem_to_warm_disk_process_std), time_warm_mem_to_warm_disk_process_std*1000))

print("{} : {}".format(varname(time_active_to_warm_disk_process_mean), time_active_to_warm_disk_process_mean*1000))
print("{} : {}".format(varname(time_active_to_warm_disk_process_std), time_active_to_warm_disk_process_std*1000))

# print("{} : {}".format(varname(time_warm_disk_to_cold_process_mean), time_warm_disk_to_cold_process_mean*1000))
# print("{} : {}".format(varname(time_warm_disk_to_cold_process_std), time_warm_disk_to_cold_process_std*1000))

print("{} : {}".format(varname(time_cold_to_null_process_mean), time_cold_to_null_process_mean*1000))
print("{} : {}".format(varname(time_cold_to_null_process_std), time_cold_to_null_process_std*1000))

# %%
# time in states
data = [time_null_to_cold_process_mean, time_warm_disk_to_warm_cpu_process_mean, 
        time_warm_cpu_to_warm_disk_process_mean, time_active_to_warm_disk_process_mean, 
        time_cold_to_null_process_mean]
error = [time_null_to_cold_process_std, time_warm_disk_to_warm_cpu_process_std, 
        time_warm_cpu_to_warm_disk_process_std, time_active_to_warm_disk_process_std, 
        time_cold_to_null_process_std]

data_1 = [time_null_to_cold_process_mean_1, time_warm_disk_to_warm_cpu_process_mean_1, 
          time_warm_cpu_to_warm_disk_process_mean_1, time_active_to_warm_disk_process_mean_1, 
          time_cold_to_null_process_mean_1]
error_1 = [time_null_to_cold_process_std_1, time_warm_disk_to_warm_cpu_process_std_1, 
          time_warm_cpu_to_warm_disk_process_std_1, time_active_to_warm_disk_process_std_1, 
          time_cold_to_null_process_std_1]

data_2 = [time_null_to_cold_process_mean_2, time_warm_disk_to_warm_cpu_process_mean_2, 
          time_warm_cpu_to_warm_disk_process_mean_2, time_active_to_warm_disk_process_mean_2, 
          time_cold_to_null_process_mean_2]
error_2 = [time_null_to_cold_process_std_2, time_warm_disk_to_warm_cpu_process_std_2, 
          time_warm_cpu_to_warm_disk_process_std_2, time_active_to_warm_disk_process_std_2, 
          time_cold_to_null_process_std_2]

state = ["Null to Cold", "Warm Disk to Warm CPU", "Warm CPU to Warm Disk", "Active to Warm Disk", "Cold to Null"]
fig, ax = plt.subplots(figsize=(10, 6))

# Plot for data
x_pos = np.arange(len(state))
ax.bar(x_pos - 0.2, data, yerr=error, width=0.2, align='center', alpha=0.9, ecolor='red', capsize=10, label='Multiple Container')

# Plot for data_1
ax.bar(x_pos, data_1, yerr=error_1, width=0.2, align='center', alpha=0.9, ecolor='blue', capsize=10, label='Multiple Process')

# Plot for data_2
ax.bar(x_pos + 0.2, data_2, yerr=error_2, width=0.2, align='center', alpha=0.9, ecolor='green', capsize=10, label='Multiple Pod')

ax.set_ylabel("Time (s)")
ax.set_xlabel("Processes ($P$)")
ax.set_xticks(x_pos)
ax.set_xticklabels(state, rotation=30)
ax.legend()
plot.yscale('log', base=10)
plot.savefig('../pdf/Time-processes-comparison.pdf', bbox_inches='tight')
plot.show()

# %%
# bw in states
data = [bw_null_to_cold_process_mean, bw_cold_to_null_process_mean, bw_warm_disk_to_warm_cpu_process_mean,
        bw_warm_cpu_to_warm_disk_process_mean, bw_active_to_warm_disk_process_mean]
error = [bw_null_to_cold_process_std, bw_null_to_cold_process_std, bw_warm_disk_to_warm_cpu_process_std,
         bw_warm_cpu_to_warm_disk_process_std, bw_active_to_warm_disk_process_std]

data_1 = [bw_null_to_cold_process_mean_1, bw_cold_to_null_process_mean_1, bw_warm_disk_to_warm_cpu_process_mean_1,
           bw_warm_cpu_to_warm_disk_process_mean_1, bw_active_to_warm_disk_process_mean_1]
error_1 = [bw_null_to_cold_process_std_1, bw_null_to_cold_process_std_1, bw_warm_disk_to_warm_cpu_process_std_1,
            bw_warm_cpu_to_warm_disk_process_std_1, bw_active_to_warm_disk_process_std_1]

data_2 = [bw_null_to_cold_process_mean_2, bw_cold_to_null_process_mean_2, bw_warm_disk_to_warm_cpu_process_mean_2,
           bw_warm_cpu_to_warm_disk_process_mean_2, bw_active_to_warm_disk_process_mean_2]
error_2 = [bw_null_to_cold_process_std_2, bw_null_to_cold_process_std_2, bw_warm_disk_to_warm_cpu_process_std_2,
            bw_warm_cpu_to_warm_disk_process_std_2, bw_active_to_warm_disk_process_std_2]

state = ["null to cold", "cold to null", "warm disk to warm cpu",
         "warm cpu to warm disk", "active to warm disk"]
fig, ax = plt.subplots(figsize=(10, 6))

# Plot for data
x_pos = np.arange(len(state))
ax.bar(x_pos - 0.2, data, yerr=error, width=0.2, align='center', alpha=0.9, ecolor='red', capsize=10, label='Multiple Container')

# Plot for data_1
ax.bar(x_pos, data_1, yerr=error_1, width=0.2, align='center', alpha=0.9, ecolor='blue', capsize=10, label='Multiple Process')

# Plot for data_2
ax.bar(x_pos + 0.2, data_2, yerr=error_2, width=0.2, align='center', alpha=0.9, ecolor='green', capsize=10, label='Multiple Pod')

ax.set_title('Bandwidth in processes')
ax.set_ylabel("Bandwidth(MBps)")
ax.set_xticks(x_pos)
ax.set_xticklabels(state, rotation=15)
ax.legend()
plot.show()
